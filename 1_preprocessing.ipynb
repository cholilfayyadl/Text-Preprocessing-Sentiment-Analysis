# %% [markdown]
# # **Preprocessing Data**

# %% [markdown]
# 1. Import modul untuk pembersihan teks, tokenisasi, analisis teks, dan manipulasi data numerik jika diperlukan dalam proses preprocessing.

# %%
import pandas as pd
import numpy as np
import nltk
import string
import re

# %% [markdown]
# 2. impor file dataset yang akan diproses.

# %%
def load_data():
    data_tweets = pd.read_csv('nu.csv')
    return data_tweets

tweets = load_data()
tweets
# Out:
#                                               full_text        id_str  \
# 0     @tempodotco Dibayar brp tuh @nahdlatululama Am...  1.770000e+32
# 1     @ZoelHayat Makanya di Indonesia ini mayoritas ...  1.770000e+29
# 2     @tants_dj @evylagi Ustad2 nu yg bener2 luas ha...  1.770000e+31
# 3     @geloraco Bukti bhwa @nahdlatululama tidak iku...  1.770000e+32
# 4     @Toto_1945 @geloraco @nahdlatululama @GusIpul_...  1.770000e+32
# ...                                                 ...           ...
# 3316  Malam Yati mpls Onad doggy on sosmed semangka ...  1.810000e+31
# 3317  PERDANA FATAYAT NU BERDIRI DI ARAB SAUDI nuonl...  1.810000e+32
# 3318  Parahnya..setelah itu jadi ketua PBNU. https:/...  1.810000e+31
# 3319  PBNU Ungkap NGO yang Sponsori Pertemuan lima N...  1.810000e+32
# 3320         cc @nahdlatululama https://t.co/0Z3iEVr0aP  1.810000e+32
#
#                      created_at       username   user_id_str lang  \
# 0     2024-04-01 00:42:32+00:00     SManikmoyo  1.240000e+32   in
# 1     2024-04-01 00:54:53+00:00  Anti_Bajingan  1.922291e+09   in
# 2     2024-04-01 01:19:07+00:00  xinyuthingker  1.330000e+31   in
# 3     2024-04-01 03:37:26+00:00      Toto_1945  9.820000e+46   in
# 4     2024-04-01 04:05:05+00:00     FashionIin  1.520000e+32   in
# ...                         ...            ...           ...  ...
# 3316  2024-07-16 16:45:39+00:00      gwizselle  1.790000e+31   in
# 3317  2024-07-16 20:50:19+00:00  AswajaKu44484  1.710000e+32   in
# 3318  2024-07-16 21:37:07+00:00   NovalAssegaf  2.438801e+08   in
# 3319  2024-07-16 22:03:36+00:00      tvOneNews  5.550737e+07   in
# 3320  2024-07-16 23:36:52+00:00      Piyusaja2  1.610000e+32  und
#
#                     location  quote_count  reply_count  retweet_count  \
# 0                     Russia            0            0              0
# 1      Trenggalek, Indonesia            0            0              0
# 2                  Mixxtopia            0            1              0
# 3                  Indonesia            0            1              0
# 4                        NaN            0            0              0
# ...                      ...          ...          ...            ...
# 3316                     NaN            0           36             13
# 3317                     NaN            0            0              0
# 3318                     NaN           13          169            177
# 3319  Pulo Gadung, Indonesia            4           16              6
# 3320                     NaN            0           17            150
#
#       favorite_count                                          tweet_url  \
# 0                  0  https://x.com/SManikmoyo/status/17745981869188...
# 1                  3  https://x.com/Anti_Bajingan/status/17746012941...
# 2                  0  https://x.com/xinyuthingker/status/17746073899...
# 3                  0  https://x.com/Toto_1945/status/177464220056093...
# 4                  0  https://x.com/FashionIin/status/17746491572545...
# ...              ...                                                ...
# 3316              38  https://x.com/gwizselle/status/181325367656547...
# 3317               1  https://x.com/AswajaKu44484/status/18133152461...
# 3318             533  https://x.com/NovalAssegaf/status/181332702524...
# 3319              18  https://x.com/tvOneNews/status/181333369045566...
# 3320             233  https://x.com/Piyusaja2/status/181335716317331...
#
#                                           mentions  mention_count  \
# 0                        tempodotco,nahdlatululama              2
# 1                                        ZoelHayat              1
# 2                                 tants_dj,evylagi              2
# 3               geloraco,nahdlatululama,GusIpul_ID              3
# 4     Toto_1945,geloraco,nahdlatululama,GusIpul_ID              4
# ...                                            ...            ...
# 3316                                           NaN              0
# 3317                                           NaN              0
# 3318                                           NaN              0
# 3319                                           NaN              0
# 3320                                nahdlatululama              1
#
#              source          target
# 0        SManikmoyo      tempodotco
# 1     Anti_Bajingan       ZoelHayat
# 2     xinyuthingker        tants_dj
# 3         Toto_1945        geloraco
# 4        FashionIin       Toto_1945
# ...             ...             ...
# 3316      gwizselle             NaN
# 3317  AswajaKu44484             NaN
# 3318   NovalAssegaf             NaN
# 3319      tvOneNews             NaN
# 3320      Piyusaja2  nahdlatululama
#
# [3321 rows x 16 columns]

# %% [markdown]
# 3. Cleaning.
# Disini ada dua tahapan cleaning; cleaning username, dan cleaning menghapus karakter tanda baca, emoticon, numerik, link dsb. Proses ini menggunakan loop dengan modul re.

# %%
#menghapus username dalam tweet
def remove_pattern(Text, pattern):
    r = re.findall(pattern, str(Text))
    for i in r:
        Text = re.sub(i, '', str(Text))
    return Text
tweets['remove_user'] = np.vectorize(remove_pattern)(tweets['full_text'], "@[\w]*")
tweets.head()
# Out:
#                                            full_text        id_str  \
# 0  @tempodotco Dibayar brp tuh @nahdlatululama Am...  1.770000e+32
# 1  @ZoelHayat Makanya di Indonesia ini mayoritas ...  1.770000e+29
# 2  @tants_dj @evylagi Ustad2 nu yg bener2 luas ha...  1.770000e+31
# 3  @geloraco Bukti bhwa @nahdlatululama tidak iku...  1.770000e+32
# 4  @Toto_1945 @geloraco @nahdlatululama @GusIpul_...  1.770000e+32
#
#                   created_at       username   user_id_str lang  \
# 0  2024-04-01 00:42:32+00:00     SManikmoyo  1.240000e+32   in
# 1  2024-04-01 00:54:53+00:00  Anti_Bajingan  1.922291e+09   in
# 2  2024-04-01 01:19:07+00:00  xinyuthingker  1.330000e+31   in
# 3  2024-04-01 03:37:26+00:00      Toto_1945  9.820000e+46   in
# 4  2024-04-01 04:05:05+00:00     FashionIin  1.520000e+32   in
#
#                 location  quote_count  reply_count  retweet_count  \
# 0                 Russia            0            0              0
# 1  Trenggalek, Indonesia            0            0              0
# 2              Mixxtopia            0            1              0
# 3              Indonesia            0            1              0
# 4                    NaN            0            0              0
#
#    favorite_count                                          tweet_url  \
# 0               0  https://x.com/SManikmoyo/status/17745981869188...
# 1               3  https://x.com/Anti_Bajingan/status/17746012941...
# 2               0  https://x.com/xinyuthingker/status/17746073899...
# 3               0  https://x.com/Toto_1945/status/177464220056093...
# 4               0  https://x.com/FashionIin/status/17746491572545...
#
#                                        mentions  mention_count         source  \
# 0                     tempodotco,nahdlatululama              2     SManikmoyo
# 1                                     ZoelHayat              1  Anti_Bajingan
# 2                              tants_dj,evylagi              2  xinyuthingker
# 3            geloraco,nahdlatululama,GusIpul_ID              3      Toto_1945
# 4  Toto_1945,geloraco,nahdlatululama,GusIpul_ID              4     FashionIin
#
#        target                                        remove_user
# 0  tempodotco                           Dibayar brp tuh  Ama 02?
# 1   ZoelHayat   Makanya di Indonesia ini mayoritas ummat isla...
# 2    tants_dj    Ustad2 nu yg bener2 luas hatinya ya buya yah...
# 3    geloraco   Bukti bhwa  tidak ikut politik praktik terban...
# 4   Toto_1945      Santai aja.. Klu gak mengakui Gak mengucap...

# %%
#cleaning
def cleaning(Text):
    Text = re.sub(r'\$\w*', '', Text)         #digunakan untuk menghapus semua kata yang dimulai dengan tanda dolar ($) dan diikuti oleh karakter huruf, angka, atau garis bawah.      #
    Text = re.sub('((www\.[^\s]+)|(https?://[^\s]+))', ' ', Text)     #untuk menghapus semua URL atau tautan web dari teks.
    Text = re.sub('&quot;'," ", Text)         #Digunakan untuk menggantikan setiap kemunculan `&quot;` dengan spasi kosong dalam kolom `text`.
    Text = re.sub(r"\d+", " ", str(Text))         #digunakan untuk menggantikan semua angka dalam teks yang disimpan dalam kolom `text` dengan spasi kosong.
    Text = re.sub(r"\b[a-zA-Z]\b", "", str(Text))     #digunakan untuk menghapus semua kata tunggal dalam teks yang disimpan dalam kolom `text`.
    Text = re.sub(r"[^\w\s]", " ", str(Text))         #digunakan untuk menggantikan semua karakter non-alphanumerik dan non-spasi dalam teks yang disimpan dalam variabel `content` dengan spasi kosong.
    Text = re.sub(r'(.)\1+', r'\1\1', Text)         #Digunakan untuk mengganti dua atau lebih karakter berulang dalam teks dengan hanya dua karakter yang berulang. Misalnya, jika terdapat karakter berulang "eeeee" dalam teks, maka akan digantikan dengan "ee".
    Text = re.sub(r"\s+", " ", str(Text))       #digunakan untuk menggantikan satu atau lebih spasi berturut-turut dalam teks
    Text = re.sub(r'#', '', Text)         #digunakan untuk menghapus semua tanda pagar (#) dalam teks
    Text = re.sub(r'[^a-zA-z0-9]', ' ', str(Text))    #Digunakan untuk menggantikan semua karakter non-alphanumerik dalam teks dengan spasi kosong, sehingga menghapus karakter-karakter tersebut dari teks dan mempertahankan hanya huruf (kapital dan kecil) serta angka.
    Text = re.sub(r'\b\w{1,2}\b', '', Text)     #digunakan untuk menghapus kata-kata dengan panjang satu atau dua karakter dalam teks
    Text = re.sub(r'\s\s+', ' ', Text)      #Digunakan untuk menggantikan dua atau lebih spasi berturut-turut dalam teks dengan satu spasi tunggal.
    Text = re.sub(r'^RT[\s]+', '', Text)        #menghapus RT
    Text = re.sub(r'^b[\s]+', '', Text)       #digunakan untuk menghapus spasi di awal teks
    Text = re.sub(r'^link[\s]+', '', Text)      #digunakan untuk menghapus string "link" yang diikuti oleh spasi di awal teks
    return Text

def remove_emoji(Text):
    emoji = re.compile("["
                        u"\U0001F600-\U0001F64F"  # emoticons
                        u"\U0001F300-\U0001F5FF"  # simbol & piktogram
                        u"\U0001F680-\U0001F6FF"  # transportasi & simbol peralatan
                        u"\U0001F1E0-\U0001F1FF"  # bendera negara
                        u"\U00002702-\U000027B0"  # simbol
                        u"\U000024C2-\U0001F251"  # emoji lainnya
                        "]+", flags=re.UNICODE)
    return emoji.sub(r'', Text)

tweets['cleaning'] = tweets['remove_user'].apply(cleaning)
tweets.head()
# Out:
#                                            full_text        id_str  \
# 0  @tempodotco Dibayar brp tuh @nahdlatululama Am...  1.770000e+32
# 1  @ZoelHayat Makanya di Indonesia ini mayoritas ...  1.770000e+29
# 2  @tants_dj @evylagi Ustad2 nu yg bener2 luas ha...  1.770000e+31
# 3  @geloraco Bukti bhwa @nahdlatululama tidak iku...  1.770000e+32
# 4  @Toto_1945 @geloraco @nahdlatululama @GusIpul_...  1.770000e+32
#
#                   created_at       username   user_id_str lang  \
# 0  2024-04-01 00:42:32+00:00     SManikmoyo  1.240000e+32   in
# 1  2024-04-01 00:54:53+00:00  Anti_Bajingan  1.922291e+09   in
# 2  2024-04-01 01:19:07+00:00  xinyuthingker  1.330000e+31   in
# 3  2024-04-01 03:37:26+00:00      Toto_1945  9.820000e+46   in
# 4  2024-04-01 04:05:05+00:00     FashionIin  1.520000e+32   in
#
#                 location  quote_count  reply_count  retweet_count  \
# 0                 Russia            0            0              0
# 1  Trenggalek, Indonesia            0            0              0
# 2              Mixxtopia            0            1              0
# 3              Indonesia            0            1              0
# 4                    NaN            0            0              0
#
#    favorite_count                                          tweet_url  \
# 0               0  https://x.com/SManikmoyo/status/17745981869188...
# 1               3  https://x.com/Anti_Bajingan/status/17746012941...
# 2               0  https://x.com/xinyuthingker/status/17746073899...
# 3               0  https://x.com/Toto_1945/status/177464220056093...
# 4               0  https://x.com/FashionIin/status/17746491572545...
#
#                                        mentions  mention_count         source  \
# 0                     tempodotco,nahdlatululama              2     SManikmoyo
# 1                                     ZoelHayat              1  Anti_Bajingan
# 2                              tants_dj,evylagi              2  xinyuthingker
# 3            geloraco,nahdlatululama,GusIpul_ID              3      Toto_1945
# 4  Toto_1945,geloraco,nahdlatululama,GusIpul_ID              4     FashionIin
#
#        target                                        remove_user  \
# 0  tempodotco                           Dibayar brp tuh  Ama 02?
# 1   ZoelHayat   Makanya di Indonesia ini mayoritas ummat isla...
# 2    tants_dj    Ustad2 nu yg bener2 luas hatinya ya buya yah...
# 3    geloraco   Bukti bhwa  tidak ikut politik praktik terban...
# 4   Toto_1945      Santai aja.. Klu gak mengakui Gak mengucap...
#
#                                             cleaning
# 0                               Dibayar brp tuh Ama
# 1   Makanya Indonesia ini mayoritas ummat islam s...
# 2   Ustad bener luas hatinya buya yahya ustad som...
# 3   Bukti bhwa tidak ikut politik praktik terbant...
# 4   Santai aja Klu gak mengakui Gak mengucap GAK ...

# %% [markdown]
# 4. Case Folding.
# Mengubah semua huruf besar menjadi huruf kecil menggunakan .str.lower()

# %%
#case folding - ubah jadi huruf kecil
tweets['case_folding'] = tweets['cleaning'].str.lower()
tweets.head()
# Out:
#                                            full_text        id_str  \
# 0  @tempodotco Dibayar brp tuh @nahdlatululama Am...  1.770000e+32
# 1  @ZoelHayat Makanya di Indonesia ini mayoritas ...  1.770000e+29
# 2  @tants_dj @evylagi Ustad2 nu yg bener2 luas ha...  1.770000e+31
# 3  @geloraco Bukti bhwa @nahdlatululama tidak iku...  1.770000e+32
# 4  @Toto_1945 @geloraco @nahdlatululama @GusIpul_...  1.770000e+32
#
#                   created_at       username   user_id_str lang  \
# 0  2024-04-01 00:42:32+00:00     SManikmoyo  1.240000e+32   in
# 1  2024-04-01 00:54:53+00:00  Anti_Bajingan  1.922291e+09   in
# 2  2024-04-01 01:19:07+00:00  xinyuthingker  1.330000e+31   in
# 3  2024-04-01 03:37:26+00:00      Toto_1945  9.820000e+46   in
# 4  2024-04-01 04:05:05+00:00     FashionIin  1.520000e+32   in
#
#                 location  quote_count  reply_count  retweet_count  \
# 0                 Russia            0            0              0
# 1  Trenggalek, Indonesia            0            0              0
# 2              Mixxtopia            0            1              0
# 3              Indonesia            0            1              0
# 4                    NaN            0            0              0
#
#    favorite_count                                          tweet_url  \
# 0               0  https://x.com/SManikmoyo/status/17745981869188...
# 1               3  https://x.com/Anti_Bajingan/status/17746012941...
# 2               0  https://x.com/xinyuthingker/status/17746073899...
# 3               0  https://x.com/Toto_1945/status/177464220056093...
# 4               0  https://x.com/FashionIin/status/17746491572545...
#
#                                        mentions  mention_count         source  \
# 0                     tempodotco,nahdlatululama              2     SManikmoyo
# 1                                     ZoelHayat              1  Anti_Bajingan
# 2                              tants_dj,evylagi              2  xinyuthingker
# 3            geloraco,nahdlatululama,GusIpul_ID              3      Toto_1945
# 4  Toto_1945,geloraco,nahdlatululama,GusIpul_ID              4     FashionIin
#
#        target                                        remove_user  \
# 0  tempodotco                           Dibayar brp tuh  Ama 02?
# 1   ZoelHayat   Makanya di Indonesia ini mayoritas ummat isla...
# 2    tants_dj    Ustad2 nu yg bener2 luas hatinya ya buya yah...
# 3    geloraco   Bukti bhwa  tidak ikut politik praktik terban...
# 4   Toto_1945      Santai aja.. Klu gak mengakui Gak mengucap...
#
#                                             cleaning  \
# 0                               Dibayar brp tuh Ama
# 1   Makanya Indonesia ini mayoritas ummat islam s...
# 2   Ustad bener luas hatinya buya yahya ustad som...
# 3   Bukti bhwa tidak ikut politik praktik terbant...
# 4   Santai aja Klu gak mengakui Gak mengucap GAK ...
#
#                                         case_folding
# 0                               dibayar brp tuh ama
# 1   makanya indonesia ini mayoritas ummat islam s...
# 2   ustad bener luas hatinya buya yahya ustad som...
# 3   bukti bhwa tidak ikut politik praktik terbant...
# 4   santai aja klu gak mengakui gak mengucap gak ...

# %%
#remove kalimat duplikat dari kolom link
tweets.drop_duplicates(subset = "case_folding", keep = 'first', inplace = True)
tweets
# Out:
#                                               full_text        id_str  \
# 0     @tempodotco Dibayar brp tuh @nahdlatululama Am...  1.770000e+32
# 1     @ZoelHayat Makanya di Indonesia ini mayoritas ...  1.770000e+29
# 2     @tants_dj @evylagi Ustad2 nu yg bener2 luas ha...  1.770000e+31
# 3     @geloraco Bukti bhwa @nahdlatululama tidak iku...  1.770000e+32
# 4     @Toto_1945 @geloraco @nahdlatululama @GusIpul_...  1.770000e+32
# ...                                                 ...           ...
# 3315  Sepertinya @nahdlatululama atau PBNU sudah lay...  1.810000e+32
# 3316  Malam Yati mpls Onad doggy on sosmed semangka ...  1.810000e+31
# 3317  PERDANA FATAYAT NU BERDIRI DI ARAB SAUDI nuonl...  1.810000e+32
# 3318  Parahnya..setelah itu jadi ketua PBNU. https:/...  1.810000e+31
# 3319  PBNU Ungkap NGO yang Sponsori Pertemuan lima N...  1.810000e+32
#
#                      created_at       username   user_id_str lang  \
# 0     2024-04-01 00:42:32+00:00     SManikmoyo  1.240000e+32   in
# 1     2024-04-01 00:54:53+00:00  Anti_Bajingan  1.922291e+09   in
# 2     2024-04-01 01:19:07+00:00  xinyuthingker  1.330000e+31   in
# 3     2024-04-01 03:37:26+00:00      Toto_1945  9.820000e+46   in
# 4     2024-04-01 04:05:05+00:00     FashionIin  1.520000e+32   in
# ...                         ...            ...           ...  ...
# 3315  2024-07-16 16:16:14+00:00      vanc1Bozz  1.620000e+32   in
# 3316  2024-07-16 16:45:39+00:00      gwizselle  1.790000e+31   in
# 3317  2024-07-16 20:50:19+00:00  AswajaKu44484  1.710000e+32   in
# 3318  2024-07-16 21:37:07+00:00   NovalAssegaf  2.438801e+08   in
# 3319  2024-07-16 22:03:36+00:00      tvOneNews  5.550737e+07   in
#
#                     location  quote_count  reply_count  retweet_count  \
# 0                     Russia            0            0              0
# 1      Trenggalek, Indonesia            0            0              0
# 2                  Mixxtopia            0            1              0
# 3                  Indonesia            0            1              0
# 4                        NaN            0            0              0
# ...                      ...          ...          ...            ...
# 3315                     NaN           10           77            102
# 3316                     NaN            0           36             13
# 3317                     NaN            0            0              0
# 3318                     NaN           13          169            177
# 3319  Pulo Gadung, Indonesia            4           16              6
#
#       favorite_count                                          tweet_url  \
# 0                  0  https://x.com/SManikmoyo/status/17745981869188...
# 1                  3  https://x.com/Anti_Bajingan/status/17746012941...
# 2                  0  https://x.com/xinyuthingker/status/17746073899...
# 3                  0  https://x.com/Toto_1945/status/177464220056093...
# 4                  0  https://x.com/FashionIin/status/17746491572545...
# ...              ...                                                ...
# 3315             248  https://x.com/vanc1Bozz/status/181324627382023...
# 3316              38  https://x.com/gwizselle/status/181325367656547...
# 3317               1  https://x.com/AswajaKu44484/status/18133152461...
# 3318             533  https://x.com/NovalAssegaf/status/181332702524...
# 3319              18  https://x.com/tvOneNews/status/181333369045566...
#
#                                           mentions  mention_count  \
# 0                        tempodotco,nahdlatululama              2
# 1                                        ZoelHayat              1
# 2                                 tants_dj,evylagi              2
# 3               geloraco,nahdlatululama,GusIpul_ID              3
# 4     Toto_1945,geloraco,nahdlatululama,GusIpul_ID              4
# ...                                            ...            ...
# 3315                         nahdlatululama,jokowi              2
# 3316                                           NaN              0
# 3317                                           NaN              0
# 3318                                           NaN              0
# 3319                                           NaN              0
#
#              source          target  \
# 0        SManikmoyo      tempodotco
# 1     Anti_Bajingan       ZoelHayat
# 2     xinyuthingker        tants_dj
# 3         Toto_1945        geloraco
# 4        FashionIin       Toto_1945
# ...             ...             ...
# 3315      vanc1Bozz  nahdlatululama
# 3316      gwizselle             NaN
# 3317  AswajaKu44484             NaN
# 3318   NovalAssegaf             NaN
# 3319      tvOneNews             NaN
#
#                                             remove_user  \
# 0                              Dibayar brp tuh  Ama 02?
# 1      Makanya di Indonesia ini mayoritas ummat isla...
# 2       Ustad2 nu yg bener2 luas hatinya ya buya yah...
# 3      Bukti bhwa  tidak ikut politik praktik terban...
# 4         Santai aja.. Klu gak mengakui Gak mengucap...
# ...                                                 ...
# 3315  Sepertinya  atau PBNU sudah layak utk dibubark...
# 3316  Malam Yati mpls Onad doggy on sosmed semangka ...
# 3317  PERDANA FATAYAT NU BERDIRI DI ARAB SAUDI nuonl...
# 3318  Parahnya..setelah itu jadi ketua PBNU. https:/...
# 3319  PBNU Ungkap NGO yang Sponsori Pertemuan lima N...
#
#                                                cleaning  \
# 0                                  Dibayar brp tuh Ama
# 1      Makanya Indonesia ini mayoritas ummat islam s...
# 2      Ustad bener luas hatinya buya yahya ustad som...
# 3      Bukti bhwa tidak ikut politik praktik terbant...
# 4      Santai aja Klu gak mengakui Gak mengucap GAK ...
# ...                                                 ...
# 3315  Sepertinya atau PBNU sudah layak utk dibubarka...
# 3316  Malam Yati mpls Onad doggy sosmed semangka Las...
# 3317  PERDANA FATAYAT BERDIRI ARAB SAUDI nuonlinenew...
# 3318              Parahnya setelah itu jadi ketua PBNU
# 3319  PBNU Ungkap NGO yang Sponsori Pertemuan lima N...
#
#                                            case_folding
# 0                                  dibayar brp tuh ama
# 1      makanya indonesia ini mayoritas ummat islam s...
# 2      ustad bener luas hatinya buya yahya ustad som...
# 3      bukti bhwa tidak ikut politik praktik terbant...
# 4      santai aja klu gak mengakui gak mengucap gak ...
# ...                                                 ...
# 3315  sepertinya atau pbnu sudah layak utk dibubarka...
# 3316  malam yati mpls onad doggy sosmed semangka las...
# 3317  perdana fatayat berdiri arab saudi nuonlinenew...
# 3318              parahnya setelah itu jadi ketua pbnu
# 3319  pbnu ungkap ngo yang sponsori pertemuan lima n...
#
# [3109 rows x 19 columns]

# %% [markdown]
# 5. Tokenisasi/Tokenized.
# Mengubah data menjadi daftar kata-kata/list. Disini menggunakan Library dari NLTK dengan mengimport fungsi word_tokenize dari modul nltk.tokenize. Dan fungsi word_tokenize_wrapper digunakan dalam kode tersebut sebagai perantara (wrapper) yang memungkinkan kita menerapkan fungsi word_tokenize dari NLTK ke setiap baris teks.

# %%
#tokenisasi - membagi kalimat jadi perkata (dipisah)
nltk.download('punkt')
from nltk.tokenize import word_tokenize

def word_tokenize_wrapper(Tweets):
    return word_tokenize(Tweets)

tweets['tokenisasi'] = tweets['case_folding'].apply(lambda x: word_tokenize_wrapper(x.lower()))
tweets.head()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
#                                            full_text        id_str  \
# 0  @tempodotco Dibayar brp tuh @nahdlatululama Am...  1.770000e+32
# 1  @ZoelHayat Makanya di Indonesia ini mayoritas ...  1.770000e+29
# 2  @tants_dj @evylagi Ustad2 nu yg bener2 luas ha...  1.770000e+31
# 3  @geloraco Bukti bhwa @nahdlatululama tidak iku...  1.770000e+32
# 4  @Toto_1945 @geloraco @nahdlatululama @GusIpul_...  1.770000e+32
#
#                   created_at       username   user_id_str lang  \
# 0  2024-04-01 00:42:32+00:00     SManikmoyo  1.240000e+32   in
# 1  2024-04-01 00:54:53+00:00  Anti_Bajingan  1.922291e+09   in
# 2  2024-04-01 01:19:07+00:00  xinyuthingker  1.330000e+31   in
# 3  2024-04-01 03:37:26+00:00      Toto_1945  9.820000e+46   in
# 4  2024-04-01 04:05:05+00:00     FashionIin  1.520000e+32   in
#
#                 location  quote_count  reply_count  retweet_count  \
# 0                 Russia            0            0              0
# 1  Trenggalek, Indonesia            0            0              0
# 2              Mixxtopia            0            1              0
# 3              Indonesia            0            1              0
# 4                    NaN            0            0              0
#
#    favorite_count                                          tweet_url  \
# 0               0  https://x.com/SManikmoyo/status/17745981869188...
# 1               3  https://x.com/Anti_Bajingan/status/17746012941...
# 2               0  https://x.com/xinyuthingker/status/17746073899...
# 3               0  https://x.com/Toto_1945/status/177464220056093...
# 4               0  https://x.com/FashionIin/status/17746491572545...
#
#                                        mentions  mention_count         source  \
# 0                     tempodotco,nahdlatululama              2     SManikmoyo
# 1                                     ZoelHayat              1  Anti_Bajingan
# 2                              tants_dj,evylagi              2  xinyuthingker
# 3            geloraco,nahdlatululama,GusIpul_ID              3      Toto_1945
# 4  Toto_1945,geloraco,nahdlatululama,GusIpul_ID              4     FashionIin
#
#        target                                        remove_user  \
# 0  tempodotco                           Dibayar brp tuh  Ama 02?
# 1   ZoelHayat   Makanya di Indonesia ini mayoritas ummat isla...
# 2    tants_dj    Ustad2 nu yg bener2 luas hatinya ya buya yah...
# 3    geloraco   Bukti bhwa  tidak ikut politik praktik terban...
# 4   Toto_1945      Santai aja.. Klu gak mengakui Gak mengucap...
#
#                                             cleaning  \
# 0                               Dibayar brp tuh Ama
# 1   Makanya Indonesia ini mayoritas ummat islam s...
# 2   Ustad bener luas hatinya buya yahya ustad som...
# 3   Bukti bhwa tidak ikut politik praktik terbant...
# 4   Santai aja Klu gak mengakui Gak mengucap GAK ...
#
#                                         case_folding  \
# 0                               dibayar brp tuh ama
# 1   makanya indonesia ini mayoritas ummat islam s...
# 2   ustad bener luas hatinya buya yahya ustad som...
# 3   bukti bhwa tidak ikut politik praktik terbant...
# 4   santai aja klu gak mengakui gak mengucap gak ...
#
#                                           tokenisasi
# 0                           [dibayar, brp, tuh, ama]
# 1  [makanya, indonesia, ini, mayoritas, ummat, is...
# 2  [ustad, bener, luas, hatinya, buya, yahya, ust...
# 3  [bukti, bhwa, tidak, ikut, politik, praktik, t...
# 4  [santai, aja, klu, gak, mengakui, gak, menguca...

# %% [markdown]
# 7. Normalisasi.
# Proses mengganti kalimat slang menjadi formal dengan menggunakan dan membaca dari kamus 'colloquial-indonesian-lexicon.csv'. Kamus ini berisi daftar kata-kata slang dan bentuk formalnya dalam bahasa Indonesia. Kemudian melakukan loop. Di dalam loop ini, setiap kata dalam teks dicek apakah ada dalam kamus dict_slang. Jika kata tersebut ada dalam kamus, maka kata slang akan diganti dengan bentuk formalnya sesuai dengan kamus. Jika kata tersebut tidak ada dalam kamus, kata tersebut tetap dipertahankan.

# %%
#Normalisasi-menormalisasikan kata yang non formal menjadi formal sesuai dengan kamus colloquial-indonesian-lexicon
def normalization (Tweets):
  tweets_slang = pd.read_csv('colloquial-indonesian-lexicon.csv')
  dict_slang ={}
  for i in range(tweets_slang.shape[0]):
    dict_slang[tweets_slang["slang"][i]]=tweets_slang["formal"][i]

  drop_slang = []
  for teks in Tweets:
    normalisasi_teks = [dict_slang[word] if word in dict_slang.keys() else word for word in teks]
    drop_slang.append(normalisasi_teks)

  return drop_slang

tweets['normalisasi'] = normalization(tweets['tokenisasi'])
tweets.head()
# Out:
#                                            full_text        id_str  \
# 0  @tempodotco Dibayar brp tuh @nahdlatululama Am...  1.770000e+32
# 1  @ZoelHayat Makanya di Indonesia ini mayoritas ...  1.770000e+29
# 2  @tants_dj @evylagi Ustad2 nu yg bener2 luas ha...  1.770000e+31
# 3  @geloraco Bukti bhwa @nahdlatululama tidak iku...  1.770000e+32
# 4  @Toto_1945 @geloraco @nahdlatululama @GusIpul_...  1.770000e+32
#
#                   created_at       username   user_id_str lang  \
# 0  2024-04-01 00:42:32+00:00     SManikmoyo  1.240000e+32   in
# 1  2024-04-01 00:54:53+00:00  Anti_Bajingan  1.922291e+09   in
# 2  2024-04-01 01:19:07+00:00  xinyuthingker  1.330000e+31   in
# 3  2024-04-01 03:37:26+00:00      Toto_1945  9.820000e+46   in
# 4  2024-04-01 04:05:05+00:00     FashionIin  1.520000e+32   in
#
#                 location  quote_count  reply_count  retweet_count  ...  \
# 0                 Russia            0            0              0  ...
# 1  Trenggalek, Indonesia            0            0              0  ...
# 2              Mixxtopia            0            1              0  ...
# 3              Indonesia            0            1              0  ...
# 4                    NaN            0            0              0  ...
#
#                                            tweet_url  \
# 0  https://x.com/SManikmoyo/status/17745981869188...
# 1  https://x.com/Anti_Bajingan/status/17746012941...
# 2  https://x.com/xinyuthingker/status/17746073899...
# 3  https://x.com/Toto_1945/status/177464220056093...
# 4  https://x.com/FashionIin/status/17746491572545...
#
#                                        mentions mention_count         source  \
# 0                     tempodotco,nahdlatululama             2     SManikmoyo
# 1                                     ZoelHayat             1  Anti_Bajingan
# 2                              tants_dj,evylagi             2  xinyuthingker
# 3            geloraco,nahdlatululama,GusIpul_ID             3      Toto_1945
# 4  Toto_1945,geloraco,nahdlatululama,GusIpul_ID             4     FashionIin
#
#        target                                        remove_user  \
# 0  tempodotco                           Dibayar brp tuh  Ama 02?
# 1   ZoelHayat   Makanya di Indonesia ini mayoritas ummat isla...
# 2    tants_dj    Ustad2 nu yg bener2 luas hatinya ya buya yah...
# 3    geloraco   Bukti bhwa  tidak ikut politik praktik terban...
# 4   Toto_1945      Santai aja.. Klu gak mengakui Gak mengucap...
#
#                                             cleaning  \
# 0                               Dibayar brp tuh Ama
# 1   Makanya Indonesia ini mayoritas ummat islam s...
# 2   Ustad bener luas hatinya buya yahya ustad som...
# 3   Bukti bhwa tidak ikut politik praktik terbant...
# 4   Santai aja Klu gak mengakui Gak mengucap GAK ...
#
#                                         case_folding  \
# 0                               dibayar brp tuh ama
# 1   makanya indonesia ini mayoritas ummat islam s...
# 2   ustad bener luas hatinya buya yahya ustad som...
# 3   bukti bhwa tidak ikut politik praktik terbant...
# 4   santai aja klu gak mengakui gak mengucap gak ...
#
#                                           tokenisasi  \
# 0                           [dibayar, brp, tuh, ama]
# 1  [makanya, indonesia, ini, mayoritas, ummat, is...
# 2  [ustad, bener, luas, hatinya, buya, yahya, ust...
# 3  [bukti, bhwa, tidak, ikut, politik, praktik, t...
# 4  [santai, aja, klu, gak, mengakui, gak, menguca...
#
#                                          normalisasi
# 0                       [dibayar, berapa, tuh, sama]
# 1  [makanya, indonesia, ini, mayoritas, ummat, is...
# 2  [ustad, benar, luas, hatinya, buya, yahya, ust...
# 3  [bukti, bahwa, tidak, ikut, politik, praktik, ...
# 4  [santai, saja, kalau, enggak, mengakui, enggak...
#
# [5 rows x 21 columns]

# %% [markdown]
# 8. Stopword Removal/Removing. Menghapus kata yang tidak memiliki makna penting. Disini menggunakan Library dari NLTK dengan modul stopword dalam bahasa indonesia. from nltk.corpus import stopwords: Kode ini mengimpor daftar stopwords (kata-kata pengisi) dalam bahasa Indonesia dari NLTK. Daftar ini akan digunakan untuk mengidentifikasi kata-kata yang harus dihapus dari teks. Dan untuk code list_stopwords_id.extend: ini merupakan list tambahakan untuk menghapus kata yang tidak ada makna selain yang disediakan dalam corpus nltk stopword.

# %%
#Stopword removal - filtering/menghapus kata yang tidak ada didalam kamus corpus nltk
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

# Bahasa Indonesia stopwords
list_stopwords_id = stopwords.words('indonesian')
list_stopwords_id.extend(['yg', 'dg', 'rt', 'dgn', 'ny', 'gt', 'klo',
                       'kalo', 'amp', 'xbf', 'xad', 'xef',
                       'xe', 'ga', 'krn', 'nya', 'nih', 'sih',
                       'si', 'xc', 'tdk', 'tuh', 'utk', 'ya',
                       'jd', 'jgn', 'sdh', 'xae', 'n', 't',
                       'nyg', 'hehe', 'pen', 'u', 'nan', 'loh', 'rt',
                       '&', 'yah', 'no', 'je', 'xbb', 'xb', 'sch',
                       'injirrr', 'ah', 'oena', 'bu', 'eh', 'xac', 'xbc', 'xf', 'xa'])

list_stopwords = set(list_stopwords_id)

def stopwords_removal(Text):
    return [word for word in Text if word not in list_stopwords]

tweets['stopword_removal'] = tweets['normalisasi'].apply(stopwords_removal)
tweets.head()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
#                                            full_text        id_str  \
# 0  @tempodotco Dibayar brp tuh @nahdlatululama Am...  1.770000e+32
# 1  @ZoelHayat Makanya di Indonesia ini mayoritas ...  1.770000e+29
# 2  @tants_dj @evylagi Ustad2 nu yg bener2 luas ha...  1.770000e+31
# 3  @geloraco Bukti bhwa @nahdlatululama tidak iku...  1.770000e+32
# 4  @Toto_1945 @geloraco @nahdlatululama @GusIpul_...  1.770000e+32
#
#                   created_at       username   user_id_str lang  \
# 0  2024-04-01 00:42:32+00:00     SManikmoyo  1.240000e+32   in
# 1  2024-04-01 00:54:53+00:00  Anti_Bajingan  1.922291e+09   in
# 2  2024-04-01 01:19:07+00:00  xinyuthingker  1.330000e+31   in
# 3  2024-04-01 03:37:26+00:00      Toto_1945  9.820000e+46   in
# 4  2024-04-01 04:05:05+00:00     FashionIin  1.520000e+32   in
#
#                 location  quote_count  reply_count  retweet_count  ...  \
# 0                 Russia            0            0              0  ...
# 1  Trenggalek, Indonesia            0            0              0  ...
# 2              Mixxtopia            0            1              0  ...
# 3              Indonesia            0            1              0  ...
# 4                    NaN            0            0              0  ...
#
#                                        mentions mention_count         source  \
# 0                     tempodotco,nahdlatululama             2     SManikmoyo
# 1                                     ZoelHayat             1  Anti_Bajingan
# 2                              tants_dj,evylagi             2  xinyuthingker
# 3            geloraco,nahdlatululama,GusIpul_ID             3      Toto_1945
# 4  Toto_1945,geloraco,nahdlatululama,GusIpul_ID             4     FashionIin
#
#        target                                        remove_user  \
# 0  tempodotco                           Dibayar brp tuh  Ama 02?
# 1   ZoelHayat   Makanya di Indonesia ini mayoritas ummat isla...
# 2    tants_dj    Ustad2 nu yg bener2 luas hatinya ya buya yah...
# 3    geloraco   Bukti bhwa  tidak ikut politik praktik terban...
# 4   Toto_1945      Santai aja.. Klu gak mengakui Gak mengucap...
#
#                                             cleaning  \
# 0                               Dibayar brp tuh Ama
# 1   Makanya Indonesia ini mayoritas ummat islam s...
# 2   Ustad bener luas hatinya buya yahya ustad som...
# 3   Bukti bhwa tidak ikut politik praktik terbant...
# 4   Santai aja Klu gak mengakui Gak mengucap GAK ...
#
#                                         case_folding  \
# 0                               dibayar brp tuh ama
# 1   makanya indonesia ini mayoritas ummat islam s...
# 2   ustad bener luas hatinya buya yahya ustad som...
# 3   bukti bhwa tidak ikut politik praktik terbant...
# 4   santai aja klu gak mengakui gak mengucap gak ...
#
#                                           tokenisasi  \
# 0                           [dibayar, brp, tuh, ama]
# 1  [makanya, indonesia, ini, mayoritas, ummat, is...
# 2  [ustad, bener, luas, hatinya, buya, yahya, ust...
# 3  [bukti, bhwa, tidak, ikut, politik, praktik, t...
# 4  [santai, aja, klu, gak, mengakui, gak, menguca...
#
#                                          normalisasi  \
# 0                       [dibayar, berapa, tuh, sama]
# 1  [makanya, indonesia, ini, mayoritas, ummat, is...
# 2  [ustad, benar, luas, hatinya, buya, yahya, ust...
# 3  [bukti, bahwa, tidak, ikut, politik, praktik, ...
# 4  [santai, saja, kalau, enggak, mengakui, enggak...
#
#                                     stopword_removal
# 0                                          [dibayar]
# 1  [indonesia, mayoritas, ummat, islam, menyimpan...
# 2  [ustad, luas, hatinya, buya, yahya, ustad, som...
# 3  [bukti, politik, praktik, terbantahkan, sekjen...
# 4          [santai, mengakui, mengucap, dideportasi]
#
# [5 rows x 22 columns]

# %% [markdown]
# 9. Stemming. Proses mengahpus imbuhan. Disini menggunakan Library sastrawi dahalam bahasa indonesia untuk menghapus imbuhannya. Modul stemmer digunakan untuk membuat objek stemmer. Sementara StopWordRemoverFactory membuat objek remover stopwords yang akan digunakan dalam tahap penghapusan, disini kasusnya seperti mengurangi noise, seperti "dan", "atau", "di", "dari", dll. Modul swifter disini berfungsi untuk mempercepat proses stemming.

# %%
#stemming - menghapus imbuhan
# !pip install swifter
# !pip install Sastrawi
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
import swifter

#buat stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

#stemmed wrapper
def stemmed_wrapper(term):
  return stemmer.stem(term)

term_dict = {}

for Tweets in tweets['stopword_removal']:
  for term in Tweets:
    if term not in term_dict:
      term_dict[term] = ' '

print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])

print(term_dict)
print("------------------------")

#memmulai stemming
def apply_stemmed_term(Tweets):
  return [term_dict[term] for term in Tweets]

tweets['stemming'] = tweets['stopword_removal'].swifter.apply(apply_stemmed_term)
tweets.head()
# Out:
# Streaming output truncated to the last 5000 lines.
# bertamu : tamu
# kapok : kapok
# membajak : bajak
# mencatut : catut
# keuntungan : untung
# memperharikan : hari
# mengklarifikasi : klarifikasi
# test : test
# ketentuan : tentu
# seragam : seragam
# kemdikbudristek : kemdikbudristek
# bawahi : bawah
# gusmen : gusmen
# busana : busana
# modis : modis
# blas : blas
# pembalap : balap
# moto : moto
# byuh : byuh
# sami : sami
# atho : atho
# berjilbab : jilbab
# pergantian : ganti
# kaosan : kaos
# jasan : jas
# apalen : apalen
# pagar : pagar
# menjadwalkan : jadwal
# persinas : persinas
# longgar : longgar
# bertukar : tukar
# derby : derby
# eropa : eropa
# timbang : timbang
# musim : musim
# penampilannya : tampil
# psg : psg
# angin : angin
# brighton : brighton
# chelsea : chelsea
# diunggulkan : unggul
# laga : laga
# superior : superior
# balal : balal
# mengkampanyekan : kampanye
# ischak : ischak
# maulana : maulana
# rohman : rohman
# fahrur : fahrur
# rozi : rozi
# alawi : alawi
# kemerdakaannya : kemerdakaannya
# secuil : cuil
# bahar : bahar
# smith : smith
# fuad : fuad
# plered : plered
# hmi : hmi
# kenyamanan : nyaman
# pemudik : mudik
# layananmudikmaksimal : layananmudikmaksimal
# memuaskan : muas
# ujung : ujung
# membayar : bayar
# segi : segi
# komunal : komunal
# islamiyah : islamiyah
# saad : saad
# tvmuhammadiyah : tvmuhammadiyah
# cerdasmencerahkan : cerdasmencerahkan
# tegakkan : tegak
# amar : amar
# ruf : ruf
# nahi : nahi
# munkar : munkar
# berprasangka : prasangka
# pesanan : pesan
# advertorial : advertorial
# nadir : nadir
# kerap : kerap
# korporasi : korporasi
# hahaa : hahaa
# digimanain : digimanain
# gugur : gugur
# syuhada : syuhada
# nassim : nassim
# taleb : taleb
# liked : liked
# eits : eits
# pemberian : beri
# mengerucut : kerucut
# gki : gki
# paper : paper
# investigates : investigates
# engaged : engaged
# soft : soft
# diplomacy : diplomacy
# suharto : suharto
# mobilise : mobilise
# vast : vast
# resources : resources
# networks : networks
# catut : catut
# dinilai : nilai
# etis : etis
# mineral : mineral
# nadirsyah : nadirsyah
# hosen : hosen
# cendikiawan : cendikiawan
# akademis : akademis
# biaya : biaya
# saku : saku
# bulanan : bulan
# lowongankerja : lowongankerja
# loker : loker
# terkini : kini
# sirep : sirep
# rebutan : rebut
# mimbar : mimbar
# mic : mic
# rbtan : rbtan
# menguasai : kuasa
# liqo : liqo
# sdng : sdng
# berbgai : berbgai
# modusnya : modus
# sasaran : sasar
# klp : klp
# chairman : chairman
# plenary : plenary
# discussion : discussion
# sacred : sacred
# ecology : ecology
# kaiciidglobalforum : kaiciidglobalforum
# transformativedialogue : transformativedialogue
# popularitas : popularitas
# menyaingi : saing
# fokus : fokus
# artist : artist
# terijabah : terijabah
# nakba : nakba
# kemerdekaan : merdeka
# freepalestine : freepalestine
# khadijah : khadijah
# independen : independen
# feminis : finis
# auto : auto
# bugil : bugil
# menghargai : harga
# mengikutkan : ikut
# perannya : peran
# mengekang : ekang
# istri : istri
# mengejar : kejar
# bakat : bakat
# minatnya : minat
# kaffah : kaffah
# tebang : tebang
# hadeeh : hadeeh
# inkubasi : inkubasi
# pembekalan : bekal
# azhar : azhar
# angkatan : angkat
# ppm : ppm
# hadi : had
# ikanu : ikanu
# mesir : mesir
# ngambil : ngambil
# menguntungkan : untung
# dirimu : diri
# pov : pov
# cawe : cawe
# taruhan : taruh
# memetik : petik
# buah : buah
# wokeh : wokeh
# beraliansi : aliansi
# eljihadetivi : eljihadetivi
# hah : hah
# lawakan : lawa
# jenis : jenis
# naah : naah
# sport : sport
# transwoman : transwoman
# diikutkan : ikut
# menanggap : tanggap
# perampasan : ampas
# lelaki : lelaki
# mempertahankan : tahan
# lgbt : lgbt
# harnessing : harnessing
# angels : angels
# raising : raising
# vibration : vibration
# salawat : salawat
# zikr : zikr
# prophetmuhammad : prophetmuhammad
# skip : skip
# berpegang : pegang
# iseas : iseas
# yusof : yusof
# ishak : ishak
# hosting : hosting
# exploring : exploring
# engagement : engagement
# hst : hst
# limnya : limnya
# ust : ust
# husnul : husnul
# muhtadi : muhtadi
# sekrtrs : sekrtrs
# rijalul : rijalul
# palmerah : palmerah
# nandar : nandar
# yuan : yuan
# dauliyah : dauliyah
# iqromullah : iqromullah
# host : host
# jum : jum
# _pukul : pukul
# selesai_ : selesai
# pramuka : pramuka
# utan : utan
# kayu : kayu
# samping : samping
# konfirmasi : konfirmasi
# _syukron : syukron
# katsiro_ : katsiro
# yhaa : yhaa
# ribut : ribut
# perkenalan : kenal
# properly : properly
# situs : situs
# rawat : rawat
# ybs : ybs
# pemadat : madat
# mumpung : mumpung
# luarbiasa : luarbiasa
# lanjutken : lanjutken
# mamah : mamah
# dedeh : dedeh
# hijaban : hijab
# valid : valid
# geplak : geplak
# kocak : kocak
# gobkok : gobkok
# idola : idola
# aisyah : aisyah
# dirampas : rampas
# laki : laki
# jejadian : jejadian
# relate : relate
# nyam : nyam
# open : open
# marriage : marriage
# multiple : multiple
# husband : husband
# monogami : monogami
# mujiburrahman : mujiburrahman
# october : october
# publication : publication
# journal : journal
# callforpaper : callforpaper
# jurnal : jurnal
# publikasiilmiah : publikasiilmiah
# jurnalilmiah : jurnalilmiah
# aseek : aseek
# tarikan : tari
# koin : koin
# inimah : inimah
# dibiayai : biaya
# grateful : grateful
# perspective : perspective
# climate : climate
# issues : issues
# along : along
# side : side
# msgr : msgr
# maroun : maroun
# gemyal : gemyal
# apostolic : apostolic
# visitor : visitor
# maronites : maronites
# laku : laku
# faizal : faizal
# assegaf : assegaf
# kritikus : kritikus
# menjual : jual
# sisa : sisa
# warisan : waris
# politiknya : politik
# watak : watak
# primodialime : primodialime
# akut : akut
# hasilnya : hasil
# raih : raih
# mempermalukan : malu
# terorisme : terorisme
# aqil : aqil
# siradj : siradj
# step : step
# darahnya : darah
# dibunuh : bunuh
# mulu : mulu
# melenceng : lenceng
# maksiat : maksiat
# public : public
# menggila : gila
# ayal : ayal
# pembajakan : baja
# mewaspadai : waspada
# pencatutan : catut
# nahloh : nahloh
# tubuhnya : tubuh
# mengedepankan : depan
# rahmah : rahmah
# harap : harap
# penundaan : tunda
# umk : umk
# sertifikathalal : sertifikathalal
# lppom_mui : lppom mui
# moderasiberagama : moderasiberagama
# tolakradikalisme : tolakradikalisme
# tolakterorisme : tolakterorisme
# tolakekstremisme : tolakekstremisme
# menyerang : serang
# habaib : habaib
# ditokohkan : tokoh
# tersembunyi : sembunyi
# ledakannya : ledak
# berkomitmen : komitmen
# lokasinya : lokasi
# sukadami : sukadami
# cikarang : cikarang
# fan : fan
# kostum : kostum
# berenang : renang
# basnas : basnas
# menyetujui : tuju
# stempel : stempel
# lur : lur
# surgi : surgi
# mufti : mufti
# kanwil : kanwil
# kalsel : kalsel
# kertaker : kertaker
# dilantiknya : lantik
# lahaji : lahaji
# imm : imm
# cenderung : cenderung
# madad : madad
# saadah : saadah
# baalawi : baalawi
# terlupakan : lupa
# beliaulah : biau
# silsilah : silsilah
# bersambung : sambung
# sayid : sayid
# basyaiban : basyaiban
# fbr : fbr
# mendaftarkan : daftar
# dpc : dpc
# transit : transit
# diperbolehkan : boleh
# pendaftaran : daftar
# pengawalan : awal
# iklan : iklan
# terindikasi : indikasi
# mengembalikan : kembali
# penjualan : jual
# komoditinya : komoditinya
# akhmad : akhmad
# wasy : wasy
# mendaftar : daftar
# notabene : notabene
# ajang : ajang
# dielukan : elu
# ndagel : ndagel
# tenan : tenan
# tulakan : tula
# madinah : madinah
# jatigunung : jatigunung
# pacitan : pacitan
# mwcnutulakan : mwcnutulakan
# dipotong : potong
# paksa : paksa
# terpotong : potong
# iklas : iklas
# moesafa : moesafa
# mwmbangun : mwmbangun
# lazisnupusat : lazisnupusat
# amaliyah : amaliyah
# tertanam : tanam
# mendarah : darah
# jiwa : jiwa
# raga : raga
# penerus : terus
# kesusahan : susah
# ukt : ukt
# fastabiqul : fastabiqul
# khoirut : khoirut
# melarang : larang
# difasilitasi : fasilitas
# dikawal : kawal
# setia : setia
# sebentar : sebentar
# pencacutan : pencacutan
# tahunya : tahu
# ketinggian : tinggi
# menyanjung : sanjung
# gub : gub
# gudangnya : gudang
# langit : langit
# buktinya : bukti
# majapahit : majapahit
# ningrat : ningrat
# shri : shri
# nareshwari : nareshwari
# pradjna : pradjna
# paramitha : paramitha
# kendedes : kendedes
# tribhuwana : tribhuwana
# tungga : tungga
# dibantai : bantai
# memasuki : pasuk
# seruan : seru
# usir : usir
# pentolan : pentol
# beredar : edar
# kumpul : kumpul
# berkumpul : kumpul
# jemursari : jemursari
# menyusun : susun
# sidrotun : sidrotun
# naim : naim
# john : john
# hendri : hendri
# purba : purba
# narasumber : narasumber
# talk : talk
# pemilihanserentak : pemilihanserentak
# rakyatawasipilkadaserentak : rakyatawasipilkadaserentak
# ditunggu : tunggu
# terjangkau : jangkau
# bersaing : saing
# sodara : sodara
# terbaik : baik
# menyelesaikan : selesai
# berprestasi : prestasi
# menjalani : jalan
# magang : magang
# sariraya : sariraya
# ltd : ltd
# jepang : jepang
# menyebabkan : sebab
# polemik : polemik
# kebebasan : bebas
# pcinujerman : pcinujerman
# nujerman : nujerman
# harkitnas : harkitnas
# perdebatan : debat
# sengit : sengit
# dinasty : dinasty
# abbasiyah : abbasiyah
# dinasti : dinasti
# alawiyah : alawiyah
# sirkular : sirkular
# tragedi : tragedi
# aktor : aktor
# tetapsemangatngaji : tetapsemangatngaji
# mahfudz : mahfudz
# kikin : kikin
# mengutamakan : utama
# memerdekakan : merdeka
# imbal : imbal
# adik : adik
# yogya : yogya
# murah : murah
# stabil : stabil
# geng : geng
# yaman : yaman
# balawi : balawi
# susupi : susup
# jongos : jongos
# oiya : oiya
# dicatut : catut
# wanti : wanti
# aksi : aksi
# lawong : lawong
# gax : gax
# getoo : getoo
# anshor : anshor
# menyenangkan : senang
# bijak : bijak
# memaknai : makna
# umy : umy
# error : error
# saudi : saudi
# suriah : suriah
# oman : om
# filipina : filipina
# membolehkan : boleh
# mubah : mubah
# muhamaddiyah : muhamaddiyah
# kecerdasan : cerdas
# hancur : hancur
# kecerdasannya : cerdas
# imbangi : imbang
# krama : krama
# hwmi : hwmi
# fuqoha : fuqoha
# pakar : pakar
# membagi : bagi
# pembuatan : buat
# problem : problem
# sifatnya : sifat
# waqi : waqi
# problemnya : problem
# yailah : yailah
# siape : siape
# sulawesi : sulawesi
# zudan : zudan
# fakrulloh : fakrulloh
# bersilaturahmi : silaturahmi
# sulsel : sulsel
# kunjungannya : kunjung
# bapa : bapa
# biasana : biasana
# joged : joged
# hajatan : hajat
# lalajo : lalajo
# mengbal : mengbal
# stadion : stadion
# lmd : lmd
# asosiasi : asosiasi
# topik : topik
# secr : secr
# taire : taire
# ral : ral
# des : des
# savants : savants
# musulmans : musulmans
# cheikh : cheikh
# rencontr : rencontr
# sienne : sienne
# cours : cours
# union : union
# certain : certain
# nombre : nombre
# questions : questions
# relatives : relatives
# aux : aux
# affaires : affaires
# mahmud : mahmud
# mattalitti : mattalitti
# dpdri : dpdri
# kabarsenator : kabarsenator
# excellency : excellency
# league : league
# scholars : scholars
# eminence : eminence
# during : during
# meeting : meeting
# discussed : discussed
# secretario : secretario
# presidente : presidente
# comisi : comisi
# ulemas : ulemas
# sheij : sheij
# reuni : reuni
# con : con
# organizaci : organizaci
# durante : durante
# abordaron : abordaron
# varias : varias
# cuestiones : cuestiones
# relacionadas : relacionadas
# los : los
# asuntos : asuntos
# aspirasinya : aspirasi
# thank : thank
# isu : isu
# perpaduan : padu
# challenges : challenges
# facing : facing
# transitioning : transitioning
# workforce : workforce
# time : time
# grant : grant
# success : success
# next : next
# welcomed : welcomed
# birmingham : birmingham
# gifted : gifted
# renaissance : renaissance
# writings : writings
# behalf : behalf
# deeply : deeply
# honoured : honoured
# recieve : recieve
# tertumpah : tumpah
# hadistnya : hadistnya
# membenci : benci
# keturunannya : turun
# diketuai : tuai
# gusnadi : gusnadi
# menganiaya : aniaya
# bali : bal
# babak : babak
# belur : bur
# water : water
# nuril : nuril
# sediain : ain
# snack : snack
# masak : masak
# bany : bany
# yesus : yesus
# apologet : apologet
# oten : oten
# kepanasan : panas
# lo : lo
# bacotanmu : bacot
# apara : apara
# pecinta : cinta
# tuan : tuan
# serendah : serendah
# mencegah : cegah
# tingginya : tinggi
# perkawinan : kawin
# tojo : tojo
# una : una
# pencegahan : cegah
# ghazali : ghazali
# unugha : unugha
# lolos : lolos
# wirausaha : wirausaha
# kebudayaan : budaya
# nucom : nucom
# inspirasi : inspirasi
# mudanya : muda
# picisan : picis
# nasbung : nasbung
# gebuk : gebuk
# tertindas : tindas
# faedah : faedah
# perusuh : rusuh
# bawahan : bawah
# dibubarkan : bubar
# among : among
# groups : groups
# reportedly : reportedly
# benefit : benefit
# mining : mining
# permit : permit
# handouts : handouts
# are : are
# claims : claims
# close : close
# smaller : smaller
# group : group
# claiming : claiming
# around : around
# wahab : wahab
# hasbullah : hasbullah
# menceritakan : cerita
# mendirikan : diri
# juru : juru
# keanggotaan : anggota
# diksinya : diksi
# naungan : naung
# didirikan : diri
# dikaruniai : karunia
# demo : demo
# sebarisan : baris
# larangan : larang
# berhaji : haj
# membentangkan : bentang
# spanduk : spanduk
# travel : travel
# kbih : kbih
# memotret : potret
# mbahas : mbahas
# disoalkan : soal
# pekikan : pekik
# bapakmu : bapak
# woi : woi
# mmlu : mmlu
# palingan : paling
# moyangmu : moyang
# nin : nin
# tanahair : tanahair
# makkah : makkah
# ajarkan : ajar
# pamer : pamer
# status : status
# teguran : tegur
# mengalir : alir
# salmanuddin : salmanuddin
# yazid : yazid
# salman : salman
# wage : wage
# amalan : amal
# harian : hari
# wetonmu : weton
# ketinggalan : tinggal
# weton : weton
# doaharian : doaharian
# heboh : heboh
# memamerkan : pamer
# inipun : ini
# disoroti : sorot
# akrab : akrab
# disapa : sapa
# rijalulansor : rijalulansor
# safinatunnajah : safinatunnajah
# setang : setang
# kedekatan : dekat
# populasi : populasi
# didominasi : dominasi
# simpatisan : simpatisan
# lantas : lantas
# adakah : ada
# figur : figur
# penantang : tantang
# lengkapnya : lengkap
# diskotik : diskotik
# wahyu : wahyu
# iqra : iqra
# tuntutlah : tuntut
# buaian : buai
# lahat : lahat
# uraian : urai
# jabarkan : jabar
# dituntut : tuntut
# hawa : hawa
# berapaham : berapaham
# pengakuan : aku
# bertolak : tolak
# penjajah : jajah
# uud : uud
# mukarom : mukarom
# krg : krg
# manfaat : manfaat
# seba : seba
# usung : usung
# nahdiyin : nahdiyin
# bersekutu : sekutu
# hti : hti
# gerombolan : gerombol
# wan : wan
# sumur : sumur
# dik : dik
# arabia : arabia
# kemakam : makam
# rasul : rasul
# cium : cium
# minoritas : minoritas
# berasal : asal
# hadamout : hadamout
# rujukan : rujuk
# wahabiyyun : wahabiyyun
# trapang : trapang
# dusun : dusun
# banyuates : banyuates
# kemampuan : mampu
# finasial : finasial
# terlaluu : terlaluu
# memujaa : memujaa
# much : much
# waisak : waisak
# merayakan : raya
# vesak : vesak
# normal : normal
# yesis : yesis
# menyelimuti : limut
# kelakuannya : laku
# kpu : kpu
# jambore : jambore
# kertasari : kertasari
# radar : radar
# penanganan : tangan
# cisanti : cisanti
# mudaratnya : mudarat
# dicekal : cekal
# buron : buron
# gesekan : gesek
# kedudukan : duduk
# amri : amri
# marwah : marwah
# taukah : tau
# numin : numin
# bagikan : bagi
# ketuapbnu : ketuapbnu
# naungannya : naung
# berkuliah : kuliah
# ptnu : ptnu
# ptkin : ptkin
# ihwaljamiyah : ihwaljamiyah
# absor : absor
# ruwatan : ruwat
# jagad : jagad
# landasan : landas
# teologis : teologis
# ekologispiritual : ekologispiritual
# jamborerelawan : jamborerelawan
# alissa : alissa
# pengarahan : arah
# mencatat : catat
# rabitha : rabitha
# awaliyah : awaliyah
# amm : amm
# menaati : taat
# tiket : tiket
# apk : apk
# panon : panon
# bareh : bareh
# jiga : jiga
# gebugan : gebugan
# gawe : gawe
# kumplit : kumplit
# reinkarnasi : reinkarnasi
# pasukan : pasu
# hisbullah : hisbullah
# berafiliasi : afiliasi
# pereksekusian : eksekusi
# cirebon : cirebon
# becak : becak
# ciayumajakuning : ciayumajakuning
# menjajah : jajah
# klaim : klaim
# koordinator : koordinator
# bogor : bogor
# japanese : japanese
# scholar : scholar
# praised : praised
# taken : taken
# deciding : deciding
# advocacy : advocacy
# orient : orient
# works : works
# toward : toward
# charter : charter
# compared : compared
# msjidnya : msjidnya
# salwatan : salwatan
# sekolh : sekolh
# krja : krja
# ngajinya : ngajinya
# kumur : kumur
# dngar : dngar
# dongkol : dongkol
# abstract : abstract
# terjemahan : terjemah
# aslinya : asli
# musyrik : musyrik
# ppsdm : ppsdm
# pwnujatim : pwnujatim
# waryono : waryono
# komisioner : komisioner
# wakaf : wakaf
# hormat : hormat
# berupaya : upaya
# diperlakukan : laku
# skema : skema
# mabit : mabit
# muzdalifah : muzdalifah
# mina : mina
# hindari : hindar
# penumpukan : tumpu
# dirjen : dirjen
# phu : phu
# transmigrasi : transmigrasi
# mendes : mendes
# pdtt : pdtt
# halim : halim
# penyiapan : siap
# jajarannya : jajar
# beristirahat : istirahat
# bhiksu : bhiksu
# respek : respek
# terselenggaranya : selenggara
# muh : muh
# dul : dul
# mengandung : kandung
# kebijaksanaan : bijaksana
# melakukannya : laku
# qadla : qadla
# dailami : dailami
# baihaqi : baihaqi
# quotes : quotes
# quotesoftheday : quotesoftheday
# quotesnuonline : quotesnuonline
# hikmah : hikmah
# jalal : jalal
# menjustifikasi : justifikasi
# olah : olah
# menyangka : sangka
# ngopi : ngopi
# ngrokokan : ngrokokan
# jebul : jebul
# koyo : koyo
# benci : benci
# duwitkah : duwitkah
# pergi : pergi
# monas : monas
# borobudur : borobudur
# univesitas : univesitas
# ngik : ngik
# kmp : kmp
# cab : cab
# tasikmalaya : tasikmalaya
# sukamanah : sukamanah
# acep : acep
# atam : atam
# rustam : rustam
# bendahara : bendahara
# festival : festival
# antarnegara : antarnegara
# seni : seni
# nafis : naf
# suni : suni
# menjamu : jamu
# serambi : serambi
# sekuku : kuku
# hitamnya : hitam
# nyali : nyali
# qoumas : qoumas
# atasannya : atas
# tour : tour
# buktikan : bukti
# didorong : dorong
# cakap : cakap
# dicalonkan : calon
# siapadia : siapadia
# headline : headline
# kotakediri : kotakediri
# rois : rois
# syuriah : syuriah
# bukhori : bukhori
# majlis : majlis
# dzikir : dzikir
# yeah : yeah
# extemist : extemist
# radical : radical
# eastern : eastern
# ideology : ideology
# only : only
# not : not
# those : those
# immigrant : immigrant
# mujahadah : mujahadah
# kelancaraan : kelancaraan
# mengisi : isi
# kubur : kubur
# kecokot : kecokot
# repot : repot
# congratulates : congratulates
# new : new
# boards : boards
# pakistan : pakistan
# result : result
# respective : respective
# annual : annual
# conferences : conferences
# held : held
# recently : recently
# mosque : mosque
# fgd : fgd
# lesbumi : lesbumi
# infonya : info
# politiknu : politiknu
# politikindonesia : politikindonesia
# erareformasi : erareformasi
# read : read
# story : story
# jabal : jabal
# sab : sab
# medium : medium
# hulu : hulu
# citarum : citarum
# perkuat : kuat
# kebencanaan : bencana
# satuan : satu
# app : app
# keislaman : islam
# terlengkap : lengkap
# android : android
# ios : ios
# dirusak : rusak
# komplotan : komplot
# digerogoti : gerogot
# ego : ego
# pucuk : pucuk
# ofset : ofset
# selaen : selaen
# sinih : sih
# gara : gara
# modelan : model
# analogi : analogi
# caper : caper
# dibodohi : bodoh
# pendirinya : diri
# mengelu : elu
# elukan : elu
# guyub : guyub
# diprank : diprank
# joins : joins
# hybrid : hybrid
# singapore : singapore
# indonesiapolitics : indonesiapolitics
# indonesiachina : indonesiachina
# geopolitics : geopolitics
# academictwitter : academictwitter
# asiapacific : asiapacific
# satire : satire
# genap : genap
# senam : senam
# pembelokan : belok
# luthfi : luthfi
# massive : massive
# klan : klan
# syahwat : syahwat
# bertindak : tindak
# phil : phil
# kamaruddin : kamaruddin
# bwi : bwi
# bakti : bakti
# glory : glory
# tamu : tamu
# bulurejo : bulurejo
# eli : eli
# cahya : cahya
# goal : goal
# kopi : kopi
# marsudi : marsudi
# griyamarsudiutomo : griyamarsudiutomo
# butengop : butengop
# kopimarsudi : kopimarsudi
# mempengbanget : banget
# morningglory : morningglory
# sundaymorningcall : sundaymorningcall
# muhamnadiyah : muhamnadiyah
# garislucu : garislucu
# dusunkarang : dusunkarang
# tet : tet
# entot : entot
# ich : ich
# finde : finde
# ehrlich : ehrlich
# gesagt : gesagt
# nicht : nicht
# wirklich : wirklich
# lustig : lustig
# wardah : wardah
# alkatiri : alkatiri
# green : green
# caliphate : caliphate
# environmental : environmental
# governance : governance
# devout : devout
# communities : communities
# miftakhul : miftakhul
# achyar : achyar
# lippo : lippo
# miftah : miftah
# dilumpuhkan : lumpuh
# waspada : waspada
# wisata : wisata
# liburan : libur
# kunjungi : kunjung
# segendeng : gendeng
# biang : biang
# benturan : bentur
# memecat : pecat
# gangguan : ganggu
# mancing : mancing
# icymi : icymi
# happening : happening
# tomorrow : tomorrow
# sign : sign
# integral : integral
# amanah : amanah
# taktis : taktis
# lincah : lincah
# ansormemanggil : ansormemanggil
# candaan : canda
# umaro : umaro
# hijrah : hijrah
# induk : induk
# disahkan : sah
# disaksikan : saksi
# dibebankan : beban
# pripun : pripun
# ungkapan : ungkap
# mengkritisi : kritisi
# wni : wni
# kulo : kulo
# nahdhiyin : nahdhiyin
# menyakiti : sakit
# kesungguhan : sungguh
# kejujuran : jujur
# padu : padu
# minimal : minimal
# menaikan : naik
# pdb : pdb
# kapita : kapita
# ratiio : ratiio
# jargon : jargon
# benteng : benteng
# wkwkwkk : wkwkwkk
# jabatanya : jabatanya
# dahlah : dah
# inaugurasi : inaugurasi
# membusungkan : busung
# memikirkan : pikir
# kegagalan : gagal
# sedulur : dulur
# nyaleg : nyaleg
# sekeluarga : keluarga
# istighfar : istighfar
# lamb : lamb
# lip : lip
# mbranang : mbranang
# mbloh : mbloh
# mbl : mbl
# astogo : astogo
# nogo : nogo
# lamunan : lamun
# panggilan : panggil
# sara : sara
# pencak : pencak
# silat : silat
# bagusan : bagus
# tersakiti : sakit
# ngibulnya : ngibulnya
# karir : karir
# khitah : khitah
# digagas : gagas
# muzadi : muzadi
# kpp : kpp
# pratama : pratama
# asahan : asah
# budi : budi
# utomo : utomo
# tugu : tugu
# sumberwringin : sumberwringin
# omes : omes
# malian : malian
# dirindukan : rindu
# pengkultusan : kultus
# melampaui : lampau
# nurani : nurani
# dikultuskan : kultus
# berbangsa : bangsa
# kehilangan : hilang
# ngibul : ngibul
# kafah : kafah
# repost : repost
# berkesempatan : sempat
# kharismatik : kharismatik
# mashum : mashum
# karepe : karepe
# muatan : muat
# politis : politis
# kandas : kandas
# pileg : pileg
# solidaritas : solidaritas
# lhah : lhah
# leres : les
# bunda : bunda
# sampun : sampun
# kelangan : kelang
# bun : bun
# bobrok : bobrok
# bosok : bosok
# menohok : tohok
# terseok : seok
# seok : seok
# pent : pent
# kemudahan : mudah
# arus : arus
# dipatuhi : patuh
# pengikutnya : ikut
# ototnya : otot
# otot : otot
# purwokerto : purwokerto
# wijaya : wijaya
# kusuma : kusuma
# welcoming : welcoming
# distinguished : distinguished
# delegation : delegation
# committee : committee
# gusdurian : gusdurian
# network : network
# asean : asean
# reconciliation : reconciliation
# ipr : ipr
# fiqh : fiqh
# manaa : manaa
# beraanii : beraanii
# modelannya : model
# biarpun : biarpun
# rela : rela
# nadliyin : nadliyin
# massa : massa
# kucing : kucing
# cokelat : cokelat
# mudzakarah : mudzakarah
# suradadi : suradadi
# mengharap : harap
# kompensasi : kompensasi
# lemparan : lempar
# tulang : tulang
# mentalnya : mental
# bangkai : bangkai
# perbuat : buat
# bayaran : bayar
# jemputan : jemput
# khas : khas
# iaitu : iaitu
# syarahan : syarah
# sempena : sempena
# turath : turath
# islami : islami
# selangor : selangor
# tajuk : tajuk
# masakini : masakini
# lawak : lawak
# realita : realita
# busuknya : busuk
# embel : embel
# aju : aju
# ngalamin : ngalamin
# bekas : bekas
# shimon : shimon
# peres : peres
# dekatnya : dekat
# dilengserkan : lengser
# mewujudkan : wujud
# masadepan : masadepan
# nkrihargamati : nkrihargamati
# indonesijaya : indonesijaya
# janganbaper : janganbaper
# kapokmu : kapok
# syukurlah : syukur
# niku : niku
# simbok : simbok
# merapat : rapat
# enak : enak
# maling : maling
# tangannya : tangan
# yakut : yakut
# kemas : kemas
# asam : asam
# sulfate : sulfate
# memakukan : paku
# perasaan : asa
# moga : moga
# berfungsi : fungsi
# kue : kue
# nipu : nipu
# mencla : mencla
# mencle : mencle
# nepotisme : nepotisme
# mbgun : mbgun
# nyiduk : nyiduk
# hoak : hoak
# zakky : zakky
# shahri : shahri
# hibahkan : hibah
# ekor : ekor
# kurban : kurban
# sebar : sebar
# pwi : pwi
# nadiem : nadiem
# dharmi : dharmi
# bercita : cita
# mimpi : mimpi
# mencukupi : cukup
# wira : wira
# wiri : wiri
# ragaku : raga
# mboten : mboten
# doakan : doa
# potensial : potensial
# ditangan : tang
# okey : okey
# barokalloh : barokalloh
# insyaallah : insyaallah
# piaraan : piara
# bernegara : negara
# eheem : eheem
# ijazah : ijazah
# alleyesonrafah : alleyesonrafah
# visa : visa
# semprot : semprot
# imad : imad
# sarman : sarman
# meureuun : meureuun
# mengamalkan : amal
# diijazahkan : ijazah
# sastra : sastra
# merespon : merespon
# marahi : marah
# sahabatpenais : sahabatpenais
# ormasislam : ormasislam
# bimasislam : bimasislam
# penais : pena
# ngisin : ngisin
# ngisini : ngisini
# alur : alur
# manfaatnya : manfaat
# antrean : antre
# membatasi : batas
# pasalnya : pasal
# menampung : tampung
# feudalisme : feudalisme
# pertengahan : tengah
# fief : fief
# dipegang : pegang
# underbuow : underbuow
# instead : instead
# kyirie : kyirie
# eleisoon : eleisoon
# kaping : kaping
# alamat : alamat
# kesayangan : sayang
# keluarkan : keluar
# pikirkan : pikir
# miskin : miskin
# dipolitisasi : politisasi
# diraih : raih
# mangzillatur : mangzillatur
# rohmah : rohmah
# batch : batch
# captionnya : captionnya
# ngawur : ngawur
# kejar : kejar
# traffic : traffic
# cacat : cacat
# berdosa : dosa
# gass : gass
# awowokwowok : awowokwowok
# wita : wita
# berhak : hak
# hope : hope
# explains : explains
# mitos : mitos
# kuasai : kuasa
# dirikan : diri
# terbongkar : bongkar
# dukungpalestina : dukungpalestina
# lagikah : lagi
# zii : zii
# berbesar : besar
# menaruh : taruh
# memenangi : tang
# haula : haula
# walaa : walaa
# quwwata : quwwata
# illa : illa
# billahil : billahil
# aliyyil : aliyyil
# adhim : adhim
# menasihati : nasihat
# rak : rak
# murur : murur
# piket : piket
# berduka : duka
# mengkritik : kritik
# puritan : puritan
# revivalis : revivalis
# islamis : islamis
# apalah : apa
# dampaknya : dampak
# faham : faham
# sangkut : sangkut
# pautnya : paut
# block : block
# najih : najih
# ghufron : ghufron
# redaksionalnya : redaksional
# konsekuen : konsekuen
# fatma : fatma
# bertetangga : tetangga
# berdampingan : damping
# pemeluk : peluk
# memperbolehkan : boleh
# pjcs : pjcs
# tangerang : tangerang
# gor : gor
# gondrong : gondrong
# taat : taat
# gotong : gotong
# royong : royong
# bpjs : bpjs
# kes : kes
# pengobatan : obat
# iuran : iur
# sedekah : sedekah
# defining : defining
# transnationalism : transnationalism
# afkar : afkar
# sundrijo : sundrijo
# jgs : jgs
# csgs : csgs
# internationalrelations : internationalrelations
# journalinternationalrelation : journalinternationalrelation
# lantik : lantik
# padaku : pada
# syansuri : syansuri
# selamatharipancasila : selamatharipancasila
# ahlulsunnah : ahlulsunnah
# waljama : waljama
# negarawan : negarawan
# election : election
# kagem : kagem
# insights : insights
# clerics : clerics
# female : female
# candidates : candidates
# elections : elections
# politics : politics
# cultural : cultural
# perspectives : perspectives
# genderstudies : genderstudies
# kewajiban : wajib
# dipertanggung : tanggung
# jawabkan : jawab
# tendensinya : tendensi
# backingnya : backingnya
# kelewatan : lewat
# tunggal : tunggal
# anggapan : anggap
# menyepakati : pakat
# prosesnya : proses
# nyenggol : nyenggol
# didasari : dasar
# bajingan : bajing
# menurunkannya : turun
# berziarah : ziarah
# penyair : sair
# pendongeng : dongeng
# zuhud : zuhud
# baghdad : baghdad
# ajar : ajar
# bangka : bangka
# seenak : enak
# jidat : jidat
# keilmuannya : ilmu
# miftahul : miftahul
# dikatai : katai
# menugaskan : tugas
# mandat : mandat
# hujat : hujat
# dibelakang : belakang
# bernama : nama
# pemerasan : peras
# menenggah : menenggah
# kebawah : bawah
# menipu : tipu
# tapera : tapera
# tegaskan : tegas
# akui : aku
# menanggapi : tanggap
# yanh : yanh
# muncul : muncul
# clear : clear
# intens : intens
# berdebat : debat
# senggol : senggol
# titip : titip
# jarimu : jari
# harimaumu : harimau
# semangan : semang
# memebela : bela
# kepetingan : peting
# bekan : bek
# mengutip : kutip
# memelihara : pelihara
# hablumminallah : hablumminallah
# hablumminannas : hablumminannas
# hablum : hablum
# teken : teken
# dibuka : buka
# mengomongnya : omong
# aselinya : aselinya
# spesifik : spesifik
# maluin : maluin
# berjanji : janji
# pertimbangan : timbang
# pengelolaan : kelola
# ame : ame
# batubara : batubara
# dikelola : kelola
# mengoptimalkan : optimal
# konsensi : konsensi
# setujukah : tuju
# apai : apa
# khittahnya : khittahnya
# kemakmuran : makmur
# pgri : pgri
# infotegal : infotegal
# cie : cie
# najis : najis
# copot : copot
# pemecah : pecah
# bag : bag
# dortmund : dortmund
# uclfinal : uclfinal
# ufc : ufc
# sungjin : sungjin
# ppkritt : ppkritt
# indigo : indigo
# oishi : oishi
# kopken : kopken
# jisoo : jisoo
# rpwp : rpwp
# uniqlo : uniqlo
# baekhyun : baekhyun
# timnasday : timnasday
# vini : vini
# madrid : madrid
# carameminumramunejkt : carameminumramunejkt
# hyunwoo : hyunwoo
# chiharu : chiharu
# shida : shida
# nami : nami
# bobotoh : bobotoh
# bellingham : bellingham
# jeff : jeff
# aporla : aporla
# blanktheseriess : blanktheseriess
# pikir : pikir
# maslahat : maslahat
# jangka : jangka
# mengerdilkan : kerdil
# terangan : terang
# menuding : tuding
# keji : keji
# tertinggi : tinggi
# masithoh : masithoh
# piyungan : piyungan
# sabet : sabet
# piala : piala
# marching : marching
# cucu : cucu
# ubaidillah : ubaidillah
# lahul : lahul
# fatiha : fatiha
# posisi : posisi
# diuntungkan : untung
# gaya : gaya
# omong : omong
# gertak : gertak
# diuji : uji
# komitmennya : komitmen
# kemudharatannya : kemudharatannya
# sawuh : sawuh
# siman : siman
# nuansa : nuansa
# ponorogohebat : ponorogohebat
# ponorogokab : ponorogokab
# barakallah : barakallah
# tuntut : tuntut
# buntut : buntut
# hina : hina
# tambangnya : tambang
# komersial : komersial
# bkpm : bkpm
# ditengah : tengah
# naiknya : naik
# kesadaran : sadar
# koar : koar
# tobat : tobat
# ekologis : ekologis
# berpeci : peci
# terbit : terbit
# again : again
# must : must
# inevitably : inevitably
# refining : refining
# strengthen : strengthen
# laws : laws
# orders : orders
# let : let
# happen : happen
# asap : asap
# lainya : lai
# organ : organ
# pengumuman : umum
# dmk : dmk
# seha : seha
# racik : racik
# perusakan : rusa
# sda : sda
# mengadu : adu
# keduniaan : dunia
# diajuin : diajuin
# sumbangan : sumbang
# sektor : sektor
# ditebas : tebas
# sekelompok : kelompok
# serakah : serakah
# panti : panti
# asuhan : asuh
# sampah : sampah
# moralitas : moralitas
# industri : industri
# dibentuk : bentuk
# ahlinya : ahli
# tempobisnis : tempobisnis
# perusak : usak
# dongok : dongok
# bisanya : bisa
# lakumdinukum : lakumdinukum
# waliyadin : waliyadin
# fisabilillah : fisabilillah
# mensahkan : sah
# ruu : ruu
# perpu : perpu
# terhambat : hambat
# shame : shame
# especially : especially
# lahirnya : lahir
# pembodohan : bodoh
# mengagungkan : agung
# medsos : medsos
# khawatir : khawatir
# berembet : rembet
# mendebat : debat
# dihina : hina
# pandailah : pandai
# bermedsos : bermedsos
# sarana : sarana
# silatul : silatul
# fikri : fikri
# warrahimi : warrahimi
# puji : puji
# memperluas : luas
# pemanfaatan : manfaat
# delphi : delphi
# charioteer : charioteer
# perunggu : perunggu
# yunani : yunani
# kuno : kuno
# arkeologi : arkeologi
# tanzania : tanzania
# persib : persib
# jilaat : jilaat
# nathalie : nathalie
# holscher : holscher
# pinggir : pinggir
# setelan : setel
# pabrik : pabrik
# pecco : pecco
# rocky : rocky
# gerung : gerung
# apologize : apologize
# sponge : sponge
# iphone : iphone
# pasrah : pasrah
# alleyesonpapua : alleyesonpapua
# kaesang : kaesang
# kenaikan : naik
# het : het
# matur : matur
# nuwun : nuwun
# bersikap : sikap
# kentara : kentara
# semestinya : mesti
# merepresentasikan : representasi
# krisis : krisis
# kepemimpi : mimpi
# siasat : siasat
# benturkan : bentur
# diinfokan : info
# meloloskan : lolos
# hidayatullah : hidayatullah
# edisi : edisi
# agen : agen
# terdekat : dekat
# asnawi : asnawi
# halamadrid : halamadrid
# boycottisrael : boycottisrael
# boycott : boycott
# suarahidayatullah : suarahidayatullah
# sdm : sdm
# modal : modal
# pemegang : pegang
# ganimah : ganimah
# rampasan : rampas
# penanaman : tanam
# meneken : teken
# tempoheadliner : tempoheadliner
# memacu : pacu
# perfroma : perfroma
# kalimantan : kalimantan
# wangi : wangi
# mbappe : mbappe
# seokjin : seokjin
# diapa : apa
# gnb : gnb
# operasional : operasional
# diambil : ambil
# berebut : rebut
# bertengkar : tengkar
# basuki : basuki
# hadimulyo : hadimulyo
# wamen : wamen
# agraria : agraria
# tataruang : tataruang
# plt : plt
# oikn : oikn
# terkemuka : muka
# memuji : puji
# pemberani : berani
# lantaran : lantar
# agustus : agustus
# permohonan : mohon
# ijintambangormas : ijintambangormas
# tambangormas : tambangormas
# menerapkan : terap
# canggih : canggih
# penyebaran : sebar
# stasiun : stasiun
# pengisian : isi
# listrik : listrik
# ruas : ruas
# tol : tol
# obesitas : obesitas
# mengibarkan : kibar
# bendera : bendera
# klub : klub
# nathan : nathan
# ssmsung : ssmsung
# hujan : hujan
# jay : jay
# idzes : idzes
# gen : gen
# khittahnu : khittahnu
# chasbullah : chasbullah
# salah fokus : salah fokus
# trendingnya : trendingnya
# bedar : bedar
# bayu : bayu
# pradana : pradana
# calvin : calvin
# verdonk : verdonk
# sunjae : sunjae
# tandatangani : tandatangani
# dilireba : dilireba
# maunya : mau
# pisau : pisau
# rendra : rendra
# andi : andi
# lugu : lugu
# polos : polos
# maklumi : maklum
# bobby : bobby
# hot : hot
# mess : mess
# khabib : khabib
# eyes : eyes
# rafah : rafah
# nadhlatululama : nadhlatululama
# izintambang : izintambang
# jatam : jatam
# pinterpolitik : pinterpolitik
# beritapolitik : beritapolitik
# restock : restock
# puma : puma
# suede : suede
# barang : barang
# impor : impor
# vietnam : vietnam
# ready : ready
# size : size
# ongkir : ongkir
# jabodetabek : jabodetabek
# diskon : diskon
# stok : stok
# putradana : putradana
# terlintas : lintas
# benak : benak
# mengizinkan : izin
# muhammadiya : muhammadiya
# kera : kera
# teroris : teroris
# berperang : perang
# lindsey : lindsey
# graham : graham
# senator : senator
# amerika : amerika
# bom : bom
# nuklir : nuklir
# menghancurkan : hancur
# americanterrorist : americanterrorist
# jtan : jtan
# kitabisa : kitabisa
# kebahagiaan : bahagia
# pengembalian : kembali
# miliar : miliar
# penipu : tipu
# dandy : dandy
# laksono : laksono
# moderate : moderate
# erase : erase
# terrorist : terrorist
# militans : militans
# because : because
# cant : cant
# mind : mind
# militia : militia
# give : give
# subhana : subhana
# watta : watta
# tanggapannya : tanggap
# ngab : ngab
# gandeng : gandeng
# gangster : gangster
# lahan : lahan
# white : white
# supernatural : supernatural
# god : god
# karunia : karunia
# langitan : langit
# maghfurlah : maghfurlah
# cengkraman : cengkraman
# pelbagai : pelbagai
# quarterly : quarterly
# launch : launch
# nunomics : nunomics
# everyday : everyday
# lifestyle : lifestyle
# financial : financial
# health : health
# assist : assist
# tool : tool
# use : use
# religious : religious
# social : social
# community : community
# kinesismoney : kinesismoney
# kinesisgold : kinesisgold
# kurtubi : kurtubi
# desak : desak
# perppu : perppu
# urgen : urgen
# mengeluarkan : keluar
# ketimbang : ketimbang
# nuonlinejombang : nuonlinejombang
# bahtsulmasail : bahtsulmasail
# tokohwanita : tokohwanita
# ningimaz : ningimaz
# perubahanzaman : perubahanzaman
# aqiqah : aqiqah
# charger : charger
# merakyat : rakyat
# wawancara : wawancara
# endy : endy
# lesmana : lesmana
# dipandu : pandu
# risty : risty
# rustarto : rustarto
# dengarkan : dengar
# rri : rri
# imp : imp
# sutradara : sutradara
# rrc : rrc
# lbp : lbp
# terjawab : jawab
# danai : dana
# teruji : uji
# kakaknya : kakak
# kerjanya : kerja
# bekali : bekal
# kebal : kebal
# ibukota : ibukota
# beroposisi : oposisi
# mosi : mosi
# menyesengsarakan : sengsara
# wadas : wadas
# pos : pos
# lomba : lomba
# agustusan : agustus
# mumpuni : mumpuni
# perangkat : perangkat
# urus : urus
# waketum : waketum
# abbas : abbas
# memangnya : memang
# diapakan : apa
# memfitnah : fitnah
# khawatirkan : khawatir
# kronologi : kronologi
# janji : janji
# temponasional : temponasional
# tugasnya : tugas
# broker : broker
# khithah : khithah
# monggo : monggo
# prepares : prepares
# coal : coal
# mine : mine
# business : business
# structure : structure
# latestnews : latestnews
# heaptalk : heaptalk
# fundraising : fundraising
# ajuurr : ajuurr
# syaiful : syaiful
# rahmat : rahmat
# naib : naib
# amirul : amirul
# hajj : hajj
# coaldesac : coaldesac
# konteksnya : konteks
# menyasar : sasar
# ritel : ritel
# dear : dear
# sawit : sawit
# terbaharukan : baharu
# zholim : zholim
# ttd : ttd
# deskripsikan : deskripsi
# rasakan : rasa
# kenal : kenal
# segan : segan
# sila : sila
# distribusi : distribusi
# menimbulkan : timbul
# mengobral : obral
# menjanjikan : janji
# operandi : operandi
# fear : fear
# mongering : mongering
# demonisasi : demon
# membenturkan : bentur
# mengungkit : ungkit
# ungkit : ungkit
# memori : memori
# historis : historis
# mengulang : ulang
# artikelhistoriaid : artikelhistoriaid
# manifesto : manifesto
# rungokno : rungokno
# memenuhi : penuh
# tanggungjawabnya : tanggungjawabnya
# mengedukasi : edukasi
# lupa : lupa
# pertanggungjawabannya : pertanggungjawabannya
# dzalim : dzalim
# sogokan : sogo
# lua : lua
# memublikasikan : publikasi
# kemnaker : kemnaker
# soroti : sorot
# sosialisasi : sosialisasi
# sorotan : sorot
# ketenagakerjaan : ketenagakerjaan
# babiknya : babiknya
# rejim : rejim
# lelucon : lelucon
# jamiah : jamiah
# afalaa : afalaa
# tastahii : tastahii
# kecewa : kecewa
# pelaksanaan : laksana
# semarak : semarak
# gebyar : gebyar
# depaann : depaann
# muak : muak
# endorse : endorse
# parasit : parasit
# jamiyah : jamiyah
# mengasosiasikan : asosiasi
# hadratussyekh : hadratussyekh
# sponsor : sponsor
# membahasnya : bahas
# dibukukan : buku
# renungkan : renung
# seyogianya : yogia
# seharus : harus
# idealisme : idealisme
# diracuni : racun
# pragmatisme : pragmatisme
# helm : helm
# kanannya : kanan
# thought : thought
# apparently : apparently
# interested : interested
# obtaining : obtaining
# license : license
# becomes : becomes
# kompascom : kompascom
# gatekke : gatekke
# iupk : iupk
# diajukan : aju
# persyaratan : syarat
# melindungi : lindung
# sabda : sabda
# rasululla : rasululla
# oalahh : oalahh
# juu : juu
# iri : iri
# tanbang : tanbang
# dijual : jual
# move : move
# administration : administration
# owned : owned
# concessions : concessions
# mounting : mounting
# scrutiny : scrutiny
# seeming : seeming
# pork : pork
# barrel : barrel
# support : support
# fikih : fikih
# terbarukan : baru
# dikeluarkan : keluar
# fokusnya : fokus
# dibidang : bidang
# berlari : lari
# alat : alat
# sbntar : sbntar
# sabgat : sabgat
# ironis : ironis
# samsak : samsak
# arogannya : arogan
# digoyang : goyang
# pilar : pilar
# kebangsatan : bangsat
# rivalitas : rivalitas
# dikemas : kemas
# sindir : sindir
# pencapaian : capai
# cold : cold
# war : war
# uni : uni
# soviet : soviet
# kaisin : kaisin
# idihh : idihh
# lemes : lemes
# nyebokin : nyebokin
# berak : berak
# mencebur : cebur
# memecah : pecah
# disandera : sandera
# utuh : utuh
# leluasa : leluasa
# mengobrak : mengobrak
# abrik : abrik
# berganti : ganti
# nki : nki
# revolusi : revolusi
# peang : peang
# membuktikan : bukti
# menjadikan : jadi
# transaksional : transaksional
# duitan : duit
# ekses : ekses
# tercipta : cipta
# dikmas : dikmas
# dijumpai : jumpa
# umroh : umroh
# kbihu : kbihu
# trenggalek : trenggalek
# ntmc : ntmc
# korlantaspolri : korlantaspolri
# ntmcchannel : ntmcchannel
# berqurban : berqurban
# yay : yay
# narahubung : narahubung
# menyambung : sambung
# ormaskeagamaan : ormaskeagamaan
# nalarpolitik : nalarpolitik
# beritapolitikterkini : beritapolitikterkini
# beritapolitikterbaru : beritapolitikterbaru
# problematik : problematik
# gejala : gejala
# horizontal : horizontal
# rakyatnya : rakyat
# berantem : antem
# melanggeng : langgeng
# pengharaman : haram
# halalkah : halal
# nehh : nehh
# cuy : cuy
# ngono : ngono
# sedari : dar
# terkenal : kenal
# kebhinekaan : kebhinekaan
# fleksibilitas : fleksibilitas
# kekinian : kini
# menginsyafi : menginsyafi
# eksistensi : eksistensi
# keberagaman : agam
# kompatriot : kompatriot
# sebangsa : bangsa
# humanitarianisme : humanitarianisme
# din : din
# kekerabatan : kerabat
# pamrih : pamrih
# simpati : simpati
# menyayangi : sayang
# ekosistem : ekosistem
# wian : wian
# dikala : kala
# ditinggal : tinggal
# berkabung : kabung
# nyiapin : nyiapin
# minuman : minum
# bingkisan : bingkis
# solat : solat
# bodo : bodo
# asu : asu
# tampan : tampan
# lampau : lampau
# memeluk : peluk
# kapitayan : kapitayan
# sesembahan : sembah
# hyang : hyang
# taya : taya
# budayawan : budayawan
# sunyoto : sunyoto
# mendiang : mendiang
# danyang : danyang
# semar : mar
# berminat : minat
# kemaruk : kemaruk
# mengeksploitasi : eksploitasi
# ajukan : aju
# pngrus : pngrus
# bwh : bwh
# smpaikan : smpaikan
# songong : songong
# buru : buru
# rentan : rentan
# aktivitas : aktivitas
# digerakkan : gerak
# diprotes : protes
# keluarnya : keluar
# hush : hush
# mengalami : alami
# beredarnya : edar
# kabarbanyuwangi : kabarbanyuwangi
# tahfidz : tahfidz
# ghoib : ghoib
# juz : juz
# tambaksumur : tambaksumur
# waru : waru
# mencetak : cetak
# mintaswasangprlopor : mintaswasangprlopor
# ayosekolahkemintaswa : ayosekolahkemintaswa
# madrasahinovatif : madrasahinovatif
# lakeh : lakeh
# khr : khr
# dicontoh : contoh
# pesat : pesat
# pragmatis : pragmatis
# merealisasikan : realisasi
# transformasi : transformasi
# terintegrasi : integrasi
# ane : ane
# legalisasi : legalisasi
# pinjol : pinjol
# judi : judi
# menyengserakan : menyengserakan
# trauma : trauma
# asabri : asabri
# jiwasraya : jiwasraya
# dislewengkan : dislewengkan
# korbannya : korban
# asik : asik
# ludah : ludah
# jilatin : jilatin
# tabayyun : tabayyun
# dibiasakan : biasa
# kesimpulan : simpul
# komoditi : komoditi
# sogok : sogok
# biasane : biasane
# mangap : mangap
# melintas : lintas
# bermlm : bermlm
# implemantasi : implemantasi
# psl : psl
# nahdlatul_uang : nahdlatul uang
# cocok : cocok
# perekonomian : ekonomi
# meninjau : tinjau
# madharatnya : madharatnya
# termarjinalkan : marjinal
# perpanjangan : panjang
# dihadapkan : hadap
# dilema : dilema
# berperan : peran
# transisi : transisi
# terjebak : jebak
# kotor : kotor
# rakus : rakus
# getahnya : getah
# jarak : jarak
# mematikan : mati
# covid : covid
# annuqayah : annuqayah
# sumatra : sumatra
# garap : garap
# insyaalloh : insyaalloh
# duitnya : duit
# values : values
# personal : personal
# memengaruhi : pengaruh
# penghidupan : hidup
# positioning : positioning
# pora : pora
# karo : karo
# gemana : gana
# jelang : jelang
# realistis : realistis
# layanan : layan
# kesehatannya : sehat
# alhamdulullah : alhamdulullah
# bertambah : tambah
# iedul : iedul
# firasat : firasat
# part : part
# syahid : syahid
# kemadu : madu
# kiainu : kiainu
# ahlifirasat : ahlifirasat
# lembaran : lembar
# usahanya : usaha
# merekrut : rekrut
# watho : watho
# atan : atan
# tumekane : tumekane
# pati : pati
# menambang : tambang
# pikirin : pikirin
# berjihad : jihad
# curahkan : curah
# harta : harta
# tsaquf : tsaquf
# menciptakan : cipta
# polarisasi : polarisasi
# menerimanya : terima
# kecemburuan : cemburu
# etua : etua
# perseroan : persero
# konsesitambang : konsesitambang
# ciri : ciri
# semboyan : semboyan
# memperkaya : kaya
# jikowo : jikowo
# adek : adek
# widiih : widiih
# sbgitu : sbgitu
# nafsunya : nafsu
# duniawi : duniawi
# berbanding : banding
# terbalik : balik
# muhamadyah : muhamadyah
# pantang : pantang
# ngemis : ngemis
# mementingkan : penting
# eksplorasi : eksplorasi
# menyesuaikan : sesuai
# menjilat : jilat
# mengemis : emis
# karakter : karakter
# panen : panen
# taubat : taubat
# videonews : videonews
# syamsuddin : syamsuddin
# berpotensi : potensi
# jebakan : jebak
# dinsyamsuddin : dinsyamsuddin
# peluang : peluang
# izinkelolatambang : izinkelolatambang
# hijau : hijau
# phdi : phdi
# dzulhijjah : dzulhijjah
# prakiraan : prakira
# ufuk : ufuk
# pemenangan : menang
# terhormat : hormat
# dipikirkan : pikir
# monitorday : monitorday
# gemas : gemas
# komenmu : komenmu
# gubluk : gubluk
# maksa : maksa
# profesimu : profesi
# sengkuni : sengkuni
# mudharatnya : mudharatnya
# suri : suri
# tauladam : tauladam
# mengoperasikan : operasi
# berbalik : balik
# ludahnya : ludah
# terjemus : jus
# lari : lari
# pendapatan : dapat
# phd : phd
# khutbahjumat : khutbahjumat
# masjidalakbarsurabaya : masjidalakbarsurabaya
# artikelnya : artikel
# cantumkan : cantum
# percepatan : cepat
# penambang : tambang
# legitimasi : legitimasi
# penambangan : tambang
# marah : marah
# bagaiman : bagaiman
# medsosnews : medsosnews
# medsosid : medsosid
# receive : receive
# concession : concession
# kaltim : kaltim
# prima : prima
# mines : mes
# vulgar : vulgar
# frasa : frasa
# brak : brak
# ribu : ribu
# urunan : urun
# kuasa : kuasa
# efekijintambang : efekijintambang
# cair : cair
# pandir : pandir
# sahnya : sah
# pertambangam : pertambangam
# kepulauan : pulau
# istikharah : istikharah
# terampil : terampil
# melukis : luk
# esdm : esdm
# bisnisupdate : bisnisupdate
# text : text
# mengertikan : erti
# menanggung : tanggung
# operator : operator
# dirancang : rancang
# satisfying : satisfying
# kuping : kuping
# pemuja : puja
# jkw : jkw
# apbn : apbn
# pekan : pekan
# diterbitkan : terbit
# grup : grup
# bakrie : bakrie
# bentar : bentar
# ude : ude
# bwakakakkak : bwakakakkak
# kpc : kpc
# carmuk : carmuk
# menyodorkan : sodor
# akwoakowow : akwoakowow
# langgar : langgar
# minerba : minerba
# yaii : yaii
# hubuddunya : hubuddunya
# merubuhkan : merubuhkan
# jutaan : juta
# cuti : cuti
# kagum : kagum
# mengajari : ajar
# berdemokrasi : demokrasi
# santun : santun
# beretika : etika
# feeling : feeling
# mencium : cium
# bau : bau
# matanya : mata
# yonoo : yonoo
# yono : yono
# podo : podo
# nang : nang
# kuburan : kubur
# wonge : wonge
# mama : mama
# kalianlah : kalian
# penbawa : penbawa
# kehancuran : hancur
# berkelas : kelas
# profesornya : profesor
# nasyirul : nasyirul
# amru : amru
# kibulin : kibulin
# kontraktor : kontraktor
# papa : papa
# kualitasnya : kualitas
# ketaker : ketaker
# ajigg : ajigg
# ngebayanginnya : ngebayanginnya
# excavator : excavator
# diatasnya : atas
# dispora : spora
# mempersembahkan : sembah
# terbantu : bantu
# ambulans : ambulans
# donasi : donasi
# orangbaik : orangbaik
# musyawaroh : musyawaroh
# konbes : konbes
# dbawah : dbawah
# mustadl : mustadl
# afin : afin
# penawaran : tawar
# tersandera : sandera
# imannya : iman
# viralnya : viralnya
# roofido : roofido
# sikapnya : sikap
# pemukiman : mukim
# ulayat : ulayat
# tempatnya : tempat
# konsesinya : konsesi
# memandang : pandang
# nonprosedural : nonprosedural
# pelakunya : laku
# kerajaan : raja
# berseberangan : berangan
# inti : inti
# hajiindonesia : hajiindonesia
# merendahkan : rendah
# tibake : tibake
# ngetroll : ngetroll
# tok : tok
# kiro : kiro
# duwur : duwur
# tbk : tbk
# intip : intip
# saudagar : saudagar
# lazim : lazim
# didengar : dengar
# aduh : aduh
# rujukannya : rujuk
# engkau : engkau
# buntung : buntung
# muhammadiah : muhammadiah
# hei : hei
# kecintaan : cinta
# daki : daki
# penandatanganan : penandatanganan
# direktorat : direktorat
# kua : kua
# sakinah : sakinah
# bersinergi : sinergi
# berlambang : lambang
# geber : geber
# petingginya : petinggi
# stigmatis : stigmatis
# logika : logika
# menipulasi : menipulasi
# wongdungupolitik : wongdungupolitik
# skelompok : skelompok
# berdonasi : donasi
# infak : infak
# salurkan : salur
# berhenti : henti
# qlam : qlam
# kritikku : kritik
# tambangbatubara : tambangbatubara
# cintaku : cinta
# keilmuanku : ilmu
# engineer : engineer
# after : after
# nearly : nearly
# four : four
# wait : wait
# very : very
# pleased : pleased
# announce : announce
# latest : latest
# research : research
# organizations : organizations
# namely : namely
# santrinya : santri
# dibelain : bain
# berjoget : joget
# jumareka : jumareka
# fungsi : fungsi
# independensi : independensi
# noted : noted
# faza : faza
# ramadhani : ramadhani
# khatam : khatam
# pondoknya : pondok
# tamil : tamil
# haflahakhirusannah : haflahakhirusannah
# ahlusunahwaljamaahanahdliyah : ahlusunahwaljamaahanahdliyah
# lost : lost
# malunya : malu
# tabungan : tabung
# akhirat : akhirat
# ass : ass
# nahdhatul : nahdhatul
# maluku : malu
# kantorkemenagburu : kantorkemenagburu
# konferwil : konferwil
# konferwilnu : konferwilnu
# konferwilnumaluku : konferwilnumaluku
# konferwilmaluku : konferwilmaluku
# nuprovinsimaluku : nuprovinsimaluku
# dwpkemenagburu : dwpkemenagburu
# dwp : dwp
# kemenagburu : kemenagburu
# onh : onh
# dikabarkan : kabar
# tertolak : tolak
# mengantongi : kantong
# keberangkatan : berangkat
# oalah : oalah
# enggak mau : enggak mau
# elektrik : elektrik
# berkaca : kaca
# barunya : baru
# timbul : timbul
# kekecewaan : kecewa
# pegiat : giat
# asman : asman
# azis : azis
# nunut : nunut
# stis : stis
# aceh : aceh
# wisuda : wisuda
# santriwan : santriwan
# santriwati : santriwati
# basa : basa
# basi : basi
# kaji : kaji
# sistemnya : sistem
# transparansi : transparansi
# keuangannya : uang
# trilliun : trilliun
# ning : ning
# qasidah : qasidah
# rebana : rebana
# harlahmuslimatnu : harlahmuslimatnu
# ningema : ningema
# emaumiyyatulchusnah : emaumiyyatulchusnah
# sahabatningema : sahabatningema
# ambisi : ambisi
# memanjakan : manja
# memenangkan : menang
# administrasi : administrasi
# dijauhkan : jauh
# penyakit : sakit
# membimbing : bimbing
# keharaman : haram
# ugm : ugm
# sependapat : dapat
# ewuh : ewuh
# pakewuh : pakewuh
# nahdkatulukama : nahdkatulukama
# pwnumaluku : pwnumaluku
# numaluku : numaluku
# konferensinwilayah : konferensinwilayah
# kemenagmalukutenggara : kemenagmalukutenggara
# mtsn : mtsn
# malra : malra
# malukutenggarahebat : malukutenggarahebat
# madrasahhebat : madrasahhebat
# malukutenggara : malukutenggara
# facebook : facebook
# hayo : hayo
# memanfaatkan : manfaat
# nuraninya : nurani
# radikalis : radikal
# alumnus : alumnus
# keagaaman : keagaaman
# penolakan : tolak
# another : another
# nahdliyins : nahdliyins
# choose : choose
# stay : stay
# bring : bring
# society : society
# bad : bad
# already : already
# known : known
# everyone : everyone
# hates : hates
# mostly : mostly
# them : them
# born : born
# someone : someone
# can : can
# manipulate : manipulate
# tergiur : giur
# kegamaan : gama
# nambang : nambang
# perspektif : perspektif
# dibanding : banding
# kumaha : maha
# betmen : betmen
# mengharumkan : harum
# awakmu : awak
# pirang : pirang
# ngurusi : ngurusi
# sembarang : sembarang
# dikapling : kapling
# dikorupsi : korupsi
# ketimbng : ketimbng
# mmgblm : mmgblm
# tangani : tangan
# gadjah : gadjah
# mada : mada
# hoalahh : hoalahh
# isinn : isinn
# siang : siang
# penciutan : ciut
# karya : karya
# pengusahaan : usaha
# pkp : pkp
# telhadap : telhadap
# dali : dal
# kitabnya : kitab
# belebut : belebut
# oliipp : oliipp
# gamo : gamo
# bental : bental
# san : san
# bwat : bwat
# talik : talik
# bermoral : moral
# tancap : tancap
# launching : launching
# koperasi : koperasi
# konawe : konawe
# istighosah : istighosah
# dilantunkan : lantun
# meniru : tiru
# elegan : elegan
# kelompoknya : kelompok
# sebabkan : sebab
# nyariin : nyariin
# kontraktornya : kontraktor
# nampung : nampung
# ngejualin : ngejualin
# dibagi : bagi
# dikadalin : dikadalin
# nadah : nadah
# devi : devi
# sihatul : sihatul
# afiah : afiah
# batalkan : batal
# declaring : declaring
# environmentally : environmentally
# damaging : damaging
# exploitation : exploitation
# natural : natural
# awarded : awarded
# now : now
# strong : strong
# enough : enough
# suaradotcom : suaradotcom
# alumniugm : alumniugm
# ormaskeagamaankelolatambang : ormaskeagamaankelolatambang
# duka : duka
# innalilahi : innalilahi
# inna : inna
# ilaihi : ilaihi
# raji : raji
# berpulang : pulang
# rahmatullah : rahmatullah
# syaifullah : syaifullah
# ibnu : ibnu
# nawawi : nawawi
# biro : biro
# baiknya : baik
# mengampuni : ampun
# ...
# dekorasi : dekorasi
# diameter : diameter
# kamar : kamar
# pasang : pasang
# tembok : tembok
# shopee : shopee
# otoritas : otoritas
# kehakiman : hakim
# zuhair : zuhair
# banseegunungkidul : banseegunungkidul
# intercivilization : intercivilization
# reception : reception
# pullman : pullman
# central : central
# park : park
# berdialog : dialog
# mengatasi : atas
# ketidakadilan : ketidakadilan
# gomar : gomar
# gultom : gultom
# tertolong : tolong
# dokumen : dokumen
# dhabi : dhabi
# menukik : tukik
# melewati : lewat
# ras : ras
# bhikkhu : bhikkhu
# nyana : nyana
# jero : jero
# mangku : mang
# pastika : pastika
# refleksi : refleksi
# antarmanusia : antarmanusia
# bergandengan : gandeng
# berlagak : lagak
# celamitan : celamitan
# syahwatmu : syahwat
# sembunyi : sembunyi
# berakhlaq : berakhlaq
# aibmu : aib
# ameera : ameera
# pmknu : pmknu
# riau : riau
# pekanbaru : pekanbaru
# numagelang : numagelang
# bangkrut : bangkrut
# rusuh : rusuh
# ngx : ngx
# ngrutan : ngrutan
# melacak : lacak
# dikota : kota
# detil : detil
# dipelosok : pelosok
# leaders : leaders
# figures : figures
# celebrated : celebrated
# ahmed : ahmed
# elders : elders
# sdi : sdi
# masjumi : masjumi
# parlemen : parlemen
# menggebuk : gebuk
# akulturasi : akulturasi
# suroan : suroan
# pemantapan : mantap
# mintaswasangpelopor : mintaswasangpelopor
# hilangnya : hilang
# wasathiyya : wasathiyya
# tasua : tasua
# nguntal : nguntal
# bilateral : bilateral
# shun : shun
# susunan : susun
# beritarembang : beritarembang
# nurfmrembang : nurfmrembang
# meramaikan : ramai
# uitm : uitm
# sembilan : sembilan
# strategik : strategik
# universiti : universiti
# bhpendidikan : bhpendidikan
# anjur : anjur
# pertukaran : tukar
# vokasi : vokasi
# uji : uji
# kemendikbudristek : kemendikbudristek
# sertifikasi : sertifikasi
# universitasnahdlatululamasurabaya : universitasnahdlatululamasurabaya
# theme : theme
# religions : religions
# civilizations : civilizations
# various : various
# ghanim : ghanim
# alghaith : alghaith
# implementing : implementing
# contribute : contribute
# promoting : promoting
# principles : principles
# human : human
# fraternity : fraternity
# socio : socio
# blok : blok
# membicarakan : bicara
# dongo : dongo
# mansoer : mansoer
# basri : basri
# sagipodin : sagipodin
# hoofdbestuur : hoofdbestuur
# nahdlatoel : nahdlatoel
# oelama : oelama
# fajar : fajar
# sodik : sodik
# bermunajat : munajat
# pakawa : pakawa
# tarumajaya : tarumajaya
# mempersulit : sulit
# udalah : uda
# keset : keset
# ansornya : ansornya
# terpacu : pacu
# tobatlah : tobat
# kian : kian
# mhm : mhm
# buatan : buat
# galaxyaifestival : galaxyaifestival
# berhadapan : hadap
# menangani : tangan
# intercivilizational : intercivilizational
# diinisiasi : inisiasi
# bungkam : bungkam
# kisruh : kisruh
# ngata : ngata
# struggle : struggle
# within : within
# robin : robin
# bush : bush
# published : published
# southeast : southeast
# asian : asi
# studies : studies
# softcover : softcover
# pages : pages
# tokobalzac : tokobalzac
# leimena : leimena
# kembangkan : kembang
# keragaman : ragam
# aiart : aiart
# palestinefree : palestinefree
# biden : biden
# klausul : klausul
# genjatan : genjatan
# didengarkan : dengar
# sin : sin
# called : called
# private : private
# wiihh : wiihh
# ngerinya : ngeri
# khoirot : khoirot
# menanamkan : tanam
# coret : coret
# kutau : tau
# jas : jas
# berkacamata : kacamata
# menyesalkan : sesal
# aowkwk : aowkwk
# setann : setann
# didegradasi : degradasi
# sanggahannya : sanggah
# hamaz : hamaz
# seniornya : senior
# kaitan : kait
# kou : kou
# lu : lu
# pembantai : bantai
# lhaa : lhaa
# bah : bah
# ditambah : tambah
# damn : damn
# cooked : cooked
# pemadam : madam
# kebakaran : bakar
# lumayan : lumayan
# nulisnya : nulisnya
# merenung : renung
# mark : mark
# twain : twain
# dikeroyok : keroyok
# ngaruh : ngaruh
# kurap : kurap
# rabbalalamin : rabbalalamin
# kudunye : kudunye
# komentarnye : komentarnye
# warganye : warganye
# utusan : utus
# atao : atao
# inisiatif : inisiatif
# oknumnye : oknumnye
# dekingan : deking
# omong doang : omong doang
# berpartner : partner
# disitu : situ
# sapa : sapa
# perhitungannya : hitung
# intelektual : intelektual
# empati : empati
# gelap : gelap
# amplopnya : amplop
# gembel : gembel
# bantahan : bantah
# ngefek : ngefek
# unusia : unusia
# menit : menit
# jiarah : jiarah
# marahnya : marah
# fasilitatornya : fasilitator
# aimep : aimep
# web : web
# directory : directory
# perbandingkan : banding
# linkedin : linkedin
# isaac : isaac
# herzog : herzog
# savic : savic
# isaacherzog : isaacherzog
# prikemanusiaan : prikemanusiaan
# lawatan : lawat
# tokohnu : tokohnu
# kuatbaca : kuatbaca
# kuatbacacom : kuatbacacom
# duluuhh : duluuhh
# maafkan : maaf
# syukron : syukron
# makmun : makmun
# zainul : zainul
# maarif : maarif
# aziz : aziz
# bahrul : bahrul
# ulum : ulum
# izza : izza
# annafisah : annafisah
# dania : dania
# diziarahin : diziarahin
# ditambangin : ditambangin
# obrolan : obrol
# dicaption : dicaption
# dikirim : kirim
# serangan : serang
# berpose : pose
# zen : zen
# filsafat : filsafat
# maya : maya
# temui : temu
# tokohmudanu : tokohmudanu
# nahdiyil : nahdiyil
# isr : isr
# sepengetahuan : tahu
# pribadinya : pribadi
# musuh : musuh
# merongrong : rongrong
# ketidakpahaman : ketidakpahaman
# geopolitik : geopolitik
# disidang : sidang
# etik : etik
# dosennya : dosen
# rombongan : rombong
# ngewakilin : ngewakilin
# kemlu : kemlu
# kepergian : pergi
# nabrak : nabrak
# onad : onad
# onar : onar
# fuck : fuck
# berfoto : foto
# suaramerdeka : suaramerdeka
# suaramerdekacom : suaramerdekacom
# presidenisrael : presidenisrael
# sumbang : sumbang
# kecoak : kecoak
# dijagal : jagal
# hey : hey
# lukai : luka
# warganu : warganu
# pres : pres
# natullah : natullah
# memposting : memposting
# capt : capt
# dimksd : dimksd
# kemesraan : mesra
# dome : dome
# rock : rock
# direbut : rebut
# pemanggilan : panggil
# hadapi : hadap
# memberangkatkan : berangkat
# zionazi : zionazi
# yasinan : yasinan
# kedewa : dewa
# sepak : sepak
# arema : arema
# nirempati : nirempati
# mempopulerkan : populer
# mendanai : dana
# pecat : pecat
# brati : brati
# berdaya : daya
# kekejaman : kejam
# mengejek : ejek
# penderitaan : derita
# menyokong : sokong
# diedit : edit
# tantrum : tantrum
# mengaktifkan : aktif
# mode : mode
# tokohkan : tokoh
# tembak : tembak
# iliihh : iliihh
# kintill : kintill
# martabat : martabat
# luluh : luluh
# lantak : lantak
# lucunya : lucu
# random : random
# backing : backing
# berkawan : kawan
# biru : biru
# nadhlatul : nadhlatul
# tuai : tuai
# kecaman : kecam
# suryani : suryani
# ngs : ngs
# ampun : ampun
# waspadai : waspada
# fatal : fatal
# merestui : restu
# keisrael : keisrael
# mengobati : obat
# terluka : luka
# pembangun : bangun
# diskriminatif : diskriminatif
# imbas : imbas
# kakran : kakran
# semangka : semangka
# konsepnya : konsep
# adaptasi : adaptasi
# teori : teori
# keterbalikan : balik
# fomo : fomo
# kutak : kutak
# kutuk : kutuk
# loknat : loknat
# laknat : laknat
# actionnya : actionnya
# packk : packk
# menghadap : hadap
# kurangnya : kurang
# lampiasin : lampiasin
# emosinya : emosi
# ditindas : tindas
# maha : maha
# pengasih : asih
# penyayang : sayang
# tuli : tuli
# kelimanya : lima
# savicali : savicali
# kaditbacacerita : kaditbacacerita
# dahulukan : dahulu
# kepalanya : kepala
# kecoaknya : kecoak
# bahagianya : bahagia
# abaikan : abai
# jeritan : jerit
# pilu : pilu
# terkasih : kasih
# benda : benda
# munawir : munawir
# anafisah : anafisah
# pencarian : cari
# menghapus : hapus
# ngapusin : ngapusin
# netanyahuunited : netanyahuunited
# kenali : kenal
# nyatut : nyatut
# rujak : rujak
# paramadina : paramadina
# menadah : tadah
# sepatutnya : patut
# wamenag : wamenag
# saiful : saiful
# menyakini : menyakini
# mendalami : dalam
# pendalaman : dalam
# limanahdliyin : limanahdliyin
# pidatonya : pidato
# izinkan : izin
# memperkenalkan : kenal
# penghamba : hamba
# semudah : mudah
# ferguso : ferguso
# bahstul : bahstul
# yunior : yunior
# kencing : kencing
# elok : elok
# resikonya : resiko
# kirinya : kiri
# utzma : utzma
# yehudit : yehudit
# ntong : ntong
# nuyapkb : nuyapkb
# pkbyanu : pkbyanu
# konstelasi : konstelasi
# difoto : foto
# rabun : rabun
# ayam : ayam
# kritisme : kritisme
# pergeseran : geser
# badrun : badrun
# alaena : alaena
# marif : marif
# anus : anus
# focus : focus
# nukeisrael : nukeisrael
# carousel : carousel
# mesra : mesra
# seranjang : ranjang
# dirugikan : rugi
# panjimasyarakat : panjimasyarakat
# diplomatik : diplomatik
# yati : yati
# mpls : mpls
# doggy : doggy
# lasem : lasem
# nuonlinenews : nuonlinenews
# auliyatul : auliyatul
# parahnya : parah
# ngo : ngo
# sponsori : sponsor
# advokat : advokat
# nirlaba : nirlaba
# mensponsori : sponsor
# {'dibayar': 'bayar', 'indonesia': 'indonesia', 'mayoritas': 'mayoritas', 'ummat': 'ummat', 'islam': 'islam', 'menyimpang': 'simpang', 'ajaran': 'ajar', 'penyebab': 'sebab', 'utamanya': 'utama', 'jongkok': 'jongkok', 'integritas': 'integritas', 'rendah': 'rendah', 'sorry': 'sorry', 'ormas': 'ormas', 'kepandiran': 'pandir', 'berjamaah': 'jamaah', 'cek': 'cek', 'wanita': 'wanita', 'ustad': 'ustad', 'luas': 'luas', 'hatinya': 'hati', 'buya': 'buya', 'yahya': 'yahya', 'somad': 'somad', 'mainnya': 'main', 'segelintir': 'gelintir', 'orang': 'orang', 'ilmunya': 'ilmu', 'dangkal': 'dangkal', 'mulutnya': 'mulut', 'lebar': 'lebar', 'bikin': 'bikin', 'kacau': 'kacau', 'bukti': 'bukti', 'politik': 'politik', 'praktik': 'praktik', 'terbantahkan': 'bantah', 'sekjen': 'sekjen', 'kemarin': 'kemarin', 'bicara': 'bicara', 'pkb': 'pkb', 'membela': 'bela', 'sampeyan': 'sampeyan', 'ngincer': 'ngincer', 'ketum': 'tum', 'mengaku': 'aku', 'gelagatnya': 'gelagat', 'santai': 'santai', 'mengakui': 'aku', 'mengucap': 'ucap', 'dideportasi': 'deportasi', 'bupati': 'bupati', 'bekasi': 'bekas', 'menghadiri': 'hadir', 'kegiatan': 'giat', 'khotmil': 'khotmil', 'qur': 'qur', 'diselenggarakan': 'selenggara', 'majelis': 'majelis', 'wakil': 'wakil', 'cabang': 'cabang', 'nahdlatul': 'nahdlatul', 'ulama': 'ulama', 'kecamatan': 'camat', 'tambun': 'tambun', 'selatan': 'selatan', 'musholla': 'musholla', 'umi': 'umi', 'bariqoh': 'bariqoh', 'perumahan': 'rumah', 'jatimulya': 'jatimulya', 'minggu': 'minggu', 'non': 'non', 'parpol': 'parpol', 'mengapai': 'kapai', 'intervensi': 'intervensi', 'malu': 'malu', 'pamanku': 'paman', 'sobat': 'sobat', 'gus': 'gus', 'dur': 'dur', 'hidup': 'hidup', 'pastinya': 'pasti', 'tegur': 'tegur', 'sang': 'sang', 'pekerjaan': 'kerja', 'tolol': 'tolol', 'jumpa': 'jumpa', 'masjid': 'masjid', 'nahdlah': 'nahdlah', 'pbnu': 'pbnu', 'makelar': 'makelar', 'saipul': 'saipul', 'kena': 'kena', 'dugaan': 'duga', 'korupsi': 'korupsi', 'bkkbi': 'bkkbi', 'tanda': 'tanda', 'lailatul': 'lailatul', 'qadar': 'qadar', 'bahudin': 'bahudin', 'nur': 'nur', 'salim': 'salim', 'pengasuh': 'asuh', 'ponpes': 'ponpes', 'narukan': 'narukan', 'rembang': 'rembang', 'ansorwonosobo': 'ansorwonosobo', 'ansorkejajar': 'ansorkejajar', 'ansor': 'ansor', 'ansormedia': 'ansormedia', 'ansormediasembungan': 'ansormediasembungan', 'banser': 'banser', 'nahdlatululama': 'nahdlatululama', 'ramadhan': 'ramadhan', 'gusabaha': 'gusabaha', 'lembaga': 'lembaga', 'pendidikan': 'didik', 'nahdliyah': 'nahdliyah', 'pengurus': 'urus', 'pondok': 'pondok', 'pesantren': 'pesantren', 'modern': 'modern', 'fasilitas': 'fasilitas', 'penerimaan': 'terima', 'santri': 'santri', 'murid': 'murid', 'kesempatan': 'sempat', 'memperoleh': 'oleh', 'beasiswa': 'beasiswa', 'kuliah': 'kuliah', 'diluar': 'luar', 'negeri': 'negeri', 'tamatan': 'tamat', 'mts': 'mts', 'ajak': 'ajak', 'ucapkan': 'ucap', 'selamat': 'selamat', 'prabowo': 'prabowo', 'gibran': 'gibran', 'utas': 'utas', 'anjuran': 'anjur', 'berbuka': 'buka', 'babi': 'babi', 'hukumnya': 'hukum', 'penistaan': 'nista', 'kah': 'kah', 'asyik': 'asyik', 'banget': 'banget', 'mudik': 'mudik', 'gratis': 'gratis', 'magetan': 'magetan', 'komandan': 'komandan', 'kodim': 'kodim', 'letkol': 'letkol', 'inf': 'inf', 'hasan': 'hasan', 'dasuki': 'dasuki', 'sos': 'sos', 'pelantikan': 'lantik', 'pimpinan': 'pimpin', 'ikatan': 'ikat', 'pelajar': 'ajar', 'putri': 'putri', 'ipnu': 'ipnu', 'ippnu': 'ippnu', 'khidmat': 'khidmat', 'senin': 'senin', 'forum': 'forum', 'wartawan': 'wartawan', 'sidoarjo': 'sidoarjo', 'forwas': 'forwas', 'pcnu': 'pcnu', 'kabupaten': 'kabupaten', 'berdiskusi': 'diskus', 'seputar': 'putar', 'ramadan': 'ramadan', 'jurnalis': 'jurnalis', 'tadarus': 'tadarus', 'beragama': 'agama', 'allah': 'allah', 'rasulnya': 'rasul', 'hadis': 'hadis', 'muhammadiyah': 'muhammadiyah', 'ldii': 'ldii', 'dll': 'dll', 'jdnya': 'jdnya', 'sesuka': 'suka', 'hati': 'hati', 'mengikut': 'ikut', 'kemauannya': 'mau', 'aturan': 'atur', 'tertangkap': 'tangkap', 'dipamerkan': 'pamer', 'muka': ' ...
# ------------------------
# Pandas Apply:   0%|          | 0/3109 [00:00<?, ?it/s]
#                                            full_text        id_str  \
# 0  @tempodotco Dibayar brp tuh @nahdlatululama Am...  1.770000e+32
# 1  @ZoelHayat Makanya di Indonesia ini mayoritas ...  1.770000e+29
# 2  @tants_dj @evylagi Ustad2 nu yg bener2 luas ha...  1.770000e+31
# 3  @geloraco Bukti bhwa @nahdlatululama tidak iku...  1.770000e+32
# 4  @Toto_1945 @geloraco @nahdlatululama @GusIpul_...  1.770000e+32
#
#                   created_at       username   user_id_str lang  \
# 0  2024-04-01 00:42:32+00:00     SManikmoyo  1.240000e+32   in
# 1  2024-04-01 00:54:53+00:00  Anti_Bajingan  1.922291e+09   in
# 2  2024-04-01 01:19:07+00:00  xinyuthingker  1.330000e+31   in
# 3  2024-04-01 03:37:26+00:00      Toto_1945  9.820000e+46   in
# 4  2024-04-01 04:05:05+00:00     FashionIin  1.520000e+32   in
#
#                 location  quote_count  reply_count  retweet_count  ...  \
# 0                 Russia            0            0              0  ...
# 1  Trenggalek, Indonesia            0            0              0  ...
# 2              Mixxtopia            0            1              0  ...
# 3              Indonesia            0            1              0  ...
# 4                    NaN            0            0              0  ...
#
#    mention_count         source      target  \
# 0              2     SManikmoyo  tempodotco
# 1              1  Anti_Bajingan   ZoelHayat
# 2              2  xinyuthingker    tants_dj
# 3              3      Toto_1945    geloraco
# 4              4     FashionIin   Toto_1945
#
#                                          remove_user  \
# 0                           Dibayar brp tuh  Ama 02?
# 1   Makanya di Indonesia ini mayoritas ummat isla...
# 2    Ustad2 nu yg bener2 luas hatinya ya buya yah...
# 3   Bukti bhwa  tidak ikut politik praktik terban...
# 4      Santai aja.. Klu gak mengakui Gak mengucap...
#
#                                             cleaning  \
# 0                               Dibayar brp tuh Ama
# 1   Makanya Indonesia ini mayoritas ummat islam s...
# 2   Ustad bener luas hatinya buya yahya ustad som...
# 3   Bukti bhwa tidak ikut politik praktik terbant...
# 4   Santai aja Klu gak mengakui Gak mengucap GAK ...
#
#                                         case_folding  \
# 0                               dibayar brp tuh ama
# 1   makanya indonesia ini mayoritas ummat islam s...
# 2   ustad bener luas hatinya buya yahya ustad som...
# 3   bukti bhwa tidak ikut politik praktik terbant...
# 4   santai aja klu gak mengakui gak mengucap gak ...
#
#                                           tokenisasi  \
# 0                           [dibayar, brp, tuh, ama]
# 1  [makanya, indonesia, ini, mayoritas, ummat, is...
# 2  [ustad, bener, luas, hatinya, buya, yahya, ust...
# 3  [bukti, bhwa, tidak, ikut, politik, praktik, t...
# 4  [santai, aja, klu, gak, mengakui, gak, menguca...
#
#                                          normalisasi  \
# 0                       [dibayar, berapa, tuh, sama]
# 1  [makanya, indonesia, ini, mayoritas, ummat, is...
# 2  [ustad, benar, luas, hatinya, buya, yahya, ust...
# 3  [bukti, bahwa, tidak, ikut, politik, praktik, ...
# 4  [santai, saja, kalau, enggak, mengakui, enggak...
#
#                                     stopword_removal  \
# 0                                          [dibayar]
# 1  [indonesia, mayoritas, ummat, islam, menyimpan...
# 2  [ustad, luas, hatinya, buya, yahya, ustad, som...
# 3  [bukti, politik, praktik, terbantahkan, sekjen...
# 4          [santai, mengakui, mengucap, dideportasi]
#
#                                             stemming
# 0                                            [bayar]
# 1  [indonesia, mayoritas, ummat, islam, simpang, ...
# 2  [ustad, luas, hati, buya, yahya, ustad, somad,...
# 3  [bukti, politik, praktik, bantah, sekjen, kema...
# 4                     [santai, aku, ucap, deportasi]
#
# [5 rows x 23 columns]

# %% [markdown]
# 10. To Sentence. Mengubah bentuk list token pada kolom stemming menjadi sentence atau kalimat.

# %%
#To Sentence/Untokenized
stemming = tweets[['stemming']]

def to_fit_sentence(Tweets):
    Tweets = np.array(Tweets)
    Tweets = ' '.join(Tweets)

    return Tweets

tweets['to_sentence'] = tweets['stemming'].apply(lambda x: to_fit_sentence(x))
tweets.head()
# Out:
#                                            full_text        id_str  \
# 0  @tempodotco Dibayar brp tuh @nahdlatululama Am...  1.770000e+32
# 1  @ZoelHayat Makanya di Indonesia ini mayoritas ...  1.770000e+29
# 2  @tants_dj @evylagi Ustad2 nu yg bener2 luas ha...  1.770000e+31
# 3  @geloraco Bukti bhwa @nahdlatululama tidak iku...  1.770000e+32
# 4  @Toto_1945 @geloraco @nahdlatululama @GusIpul_...  1.770000e+32
#
#                   created_at       username   user_id_str lang  \
# 0  2024-04-01 00:42:32+00:00     SManikmoyo  1.240000e+32   in
# 1  2024-04-01 00:54:53+00:00  Anti_Bajingan  1.922291e+09   in
# 2  2024-04-01 01:19:07+00:00  xinyuthingker  1.330000e+31   in
# 3  2024-04-01 03:37:26+00:00      Toto_1945  9.820000e+46   in
# 4  2024-04-01 04:05:05+00:00     FashionIin  1.520000e+32   in
#
#                 location  quote_count  reply_count  retweet_count  ...  \
# 0                 Russia            0            0              0  ...
# 1  Trenggalek, Indonesia            0            0              0  ...
# 2              Mixxtopia            0            1              0  ...
# 3              Indonesia            0            1              0  ...
# 4                    NaN            0            0              0  ...
#
#           source      target  \
# 0     SManikmoyo  tempodotco
# 1  Anti_Bajingan   ZoelHayat
# 2  xinyuthingker    tants_dj
# 3      Toto_1945    geloraco
# 4     FashionIin   Toto_1945
#
#                                          remove_user  \
# 0                           Dibayar brp tuh  Ama 02?
# 1   Makanya di Indonesia ini mayoritas ummat isla...
# 2    Ustad2 nu yg bener2 luas hatinya ya buya yah...
# 3   Bukti bhwa  tidak ikut politik praktik terban...
# 4      Santai aja.. Klu gak mengakui Gak mengucap...
#
#                                             cleaning  \
# 0                               Dibayar brp tuh Ama
# 1   Makanya Indonesia ini mayoritas ummat islam s...
# 2   Ustad bener luas hatinya buya yahya ustad som...
# 3   Bukti bhwa tidak ikut politik praktik terbant...
# 4   Santai aja Klu gak mengakui Gak mengucap GAK ...
#
#                                         case_folding  \
# 0                               dibayar brp tuh ama
# 1   makanya indonesia ini mayoritas ummat islam s...
# 2   ustad bener luas hatinya buya yahya ustad som...
# 3   bukti bhwa tidak ikut politik praktik terbant...
# 4   santai aja klu gak mengakui gak mengucap gak ...
#
#                                           tokenisasi  \
# 0                           [dibayar, brp, tuh, ama]
# 1  [makanya, indonesia, ini, mayoritas, ummat, is...
# 2  [ustad, bener, luas, hatinya, buya, yahya, ust...
# 3  [bukti, bhwa, tidak, ikut, politik, praktik, t...
# 4  [santai, aja, klu, gak, mengakui, gak, menguca...
#
#                                          normalisasi  \
# 0                       [dibayar, berapa, tuh, sama]
# 1  [makanya, indonesia, ini, mayoritas, ummat, is...
# 2  [ustad, benar, luas, hatinya, buya, yahya, ust...
# 3  [bukti, bahwa, tidak, ikut, politik, praktik, ...
# 4  [santai, saja, kalau, enggak, mengakui, enggak...
#
#                                     stopword_removal  \
# 0                                          [dibayar]
# 1  [indonesia, mayoritas, ummat, islam, menyimpan...
# 2  [ustad, luas, hatinya, buya, yahya, ustad, som...
# 3  [bukti, politik, praktik, terbantahkan, sekjen...
# 4          [santai, mengakui, mengucap, dideportasi]
#
#                                             stemming  \
# 0                                            [bayar]
# 1  [indonesia, mayoritas, ummat, islam, simpang, ...
# 2  [ustad, luas, hati, buya, yahya, ustad, somad,...
# 3  [bukti, politik, praktik, bantah, sekjen, kema...
# 4                     [santai, aku, ucap, deportasi]
#
#                                          to_sentence
# 0                                              bayar
# 1  indonesia mayoritas ummat islam simpang ajar i...
# 2  ustad luas hati buya yahya ustad somad main us...
# 3  bukti politik praktik bantah sekjen kemarin bi...
# 4                          santai aku ucap deportasi
#
# [5 rows x 24 columns]

# %% [markdown]
# 11. Save kedalam csv

# %%
#simpan kedalam csv
tweets.to_csv('preprocessing-nu-1.csv', sep=',', index=False)

# %% [markdown]
# Link kamus normalisasi (colloquial-indonesian-lexicon.csv) : https://medium.com/@arie.pratama.s/bahasa-indonesia-open-sourced-nlp-resources-8cb394193238
